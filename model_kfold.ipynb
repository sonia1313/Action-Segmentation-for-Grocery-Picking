# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/Othercomputers/Dell/Action-Segmentation-Project")

# %%
# !pwd
# Out:
# /content/drive/Othercomputers/Dell/Action-Segmentation-Project

# %%
! pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.7.0-py3-none-any.whl (700 kB)
#      |████████████████████████████████| 700 kB 2.7 MB/s
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 56.9 MB/s
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 49.3 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.6)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.1.1)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.9 MB/s
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 53.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.4.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.47.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (3.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.1.0)
# Installing collected packages: fsspec, torchmetrics, tensorboard, PyYAML, pyDeprecate, pytorch-lightning
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.9.1 which is incompatible.
# Successfully installed PyYAML-6.0 fsspec-2022.7.1 pyDeprecate-0.3.2 pytorch-lightning-1.7.0 tensorboard-2.9.1 torchmetrics-0.9.3

# %%
! pip install wandb -qU
# Out:
#      |████████████████████████████████| 1.8 MB 4.0 MB/s
#      |████████████████████████████████| 156 kB 68.3 MB/s
#      |████████████████████████████████| 181 kB 69.8 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#   Building wheel for pathtools (setup.py) ... done

# %%
# import main_2
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
! python tcn_kfold.py -f tcn_baseline.yaml
# Out:
# Global seed set to 42
# Tesla P100-PCIE-16GB
# no_sequences:59
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logging/tcn_testing2/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type             | Params
# ------------------------------------------------------
# 0 | tcn              | TemporalConvNet  | 479 K
# 1 | loss_module      | CrossEntropyLoss | 0
# 2 | train_acc        | Accuracy         | 0
# 3 | val_acc          | Accuracy         | 0
# 4 | test_acc         | Accuracy         | 0
# 5 | confusion_matrix | ConfusionMatrix  | 0
# ------------------------------------------------------
# 479 K     Trainable params
# 0         Non-trainable params
# 479 K     Total params
# 1.916     Total estimated model params size (MB)
# STARTING FOLD 0
# wandb: Currently logged in as: soniamathews. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path wandb_runs/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path wandb_runs/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_190948-current_fold_0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run current_fold_0
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_0
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1895: PossibleUserWarning: The number of training batches (44) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  73% 40/55 [00:30<00:11,  1.29it/s, loss=1.77, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Epoch 0: 100% 55/55 [00:40<00:00,  1.36it/s, loss=1.74, v_num=0, val_loss=1.650, val_acc=0.313]
# Epoch 0: 100% 55/55 [00:40<00:00,  1.36it/s, loss=1.74, v_num=0, val_loss=1.650, val_acc=0.313, train_acc=0.151]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 55/55 [00:40<00:00,  1.35it/s, loss=1.74, v_num=0, val_loss=1.650, val_acc=0.313, train_acc=0.151]
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.65it/s]average test f1 overlap @ 10%: 26.267857142857146
# average test f1 overlap @ 25%: 26.267857142857146
# average test f1 overlap @ 50%: 15.696428571428573
# average test edit: 21.607142857142858
# average test accuracy : 0.4398534297943115
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.64it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.4398534297943115
#         test_loss            1.478236198425293
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁
# wandb:      average_val_edit ▁
# wandb:     average_val_f1_10 ▁
# wandb:     average_val_f1_25 ▁
# wandb:     average_val_f1_50 ▁
# wandb:            edit_score ▃▅▄▁▁▄▄▅▅▇▅▅▁▁▄▄▃▃▆▄▃▅▄▅▅▄▇▅▄▆▅▇▇█▆▃▆▇▆▆
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         f1_overlap_10 ▃▁▅▁▁▁▄▆▄▄▅▄▁▁▁▃▂▃█▁▃▆▂▃▁▃▅▂▃▅▅▄▄▄▅▂▆▆▄▇
# wandb:         f1_overlap_25 ▃▁▁▁▁▁▅▇▃▄▃▄▁▁▁▄▁▃▄▁▁█▁▃▁▃▆▂▃▆▄▄▁▅▃▂▇▅▅█
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▆▁▄▆▁▁▁▁▁▅▁▁▁▁▁▆▁▂▁▁▁▁▁█▁▁▁▄▁▁▄▄▁▁
# wandb:         test_accuracy ▁▅█▃
# wandb:             test_loss █▃▁▃
# wandb:        train_accuracy ▅▁▂▁▁▁▆▃▆▄▆▂▁▁▁▂▃▃▃▁▂▄▄▂▁▂▆▃▆▄▄▃▃▃▅▅▇▇█▆
# wandb:            train_loss ▂█▇▆▄▅▃▄▃▄▄▃▄▄▅▄▄▄▄▄▄▄▃▃▄▃▃▄▃▃▃▃▃▂▃▂▂▁▂▁
# wandb:          val_accuracy ▄▃▇▃▅▅▁▅▅█▃
# wandb:        val_edit_score ▃▃▁▇▇▅▃▅▃▃█
# wandb:     val_f1_overlap_10 ▂▃▂▂▇▄▃▁▃█▄
# wandb:     val_f1_overlap_25 ▄▅▅▁▄▅▁▄▃█▃
# wandb:     val_f1_overlap_50 ▄▁█▁▁▁▁▆▅█▁
# wandb:              val_loss ▄▆▃█▂▄█▂▄▁▅
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.43985
# wandb:     average_test_edit 21.60714
# wandb:    average_test_f1_10 26.26786
# wandb:    average_test_f1_25 26.26786
# wandb:    average_test_f1_50 15.69643
# wandb:  average_val_accuracy 0.31258
# wandb:      average_val_edit 23.347
# wandb:     average_val_f1_10 24.08062
# wandb:     average_val_f1_25 16.6426
# wandb:     average_val_f1_50 6.91087
# wandb:            edit_score 20.0
# wandb:                 epoch 0
# wandb:         f1_overlap_10 22.22222
# wandb:         f1_overlap_25 22.22222
# wandb:         f1_overlap_50 0.0
# wandb:         test_accuracy 0.38554
# wandb:             test_loss 1.45451
# wandb:        train_accuracy 0.31183
# wandb:            train_loss 1.63405
# wandb:          val_accuracy 0.22662
# wandb:        val_edit_score 31.57895
# wandb:     val_f1_overlap_10 24.24242
# wandb:     val_f1_overlap_25 12.12121
# wandb:     val_f1_overlap_50 0.0
# wandb:              val_loss 1.68967
# wandb:
# wandb: Synced current_fold_0: https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_0
# wandb: Synced 5 W&B file(s), 59 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_190948-current_fold_0/logs
# STARTING FOLD 1
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_191036-current_fold_1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run current_fold_1
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_1
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1895: PossibleUserWarning: The number of training batches (44) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  73% 40/55 [00:34<00:13,  1.15it/s, loss=1.64, v_num=0, val_loss=1.650, val_acc=0.313, train_acc=0.151, test_loss=1.480, test_acc=0.440]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Epoch 0: 100% 55/55 [00:46<00:00,  1.19it/s, loss=1.58, v_num=0, val_loss=1.430, val_acc=0.417, train_acc=0.151, test_loss=1.480, test_acc=0.440]
# Epoch 0: 100% 55/55 [00:46<00:00,  1.19it/s, loss=1.58, v_num=0, val_loss=1.430, val_acc=0.417, train_acc=0.248, test_loss=1.480, test_acc=0.440]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 55/55 [00:46<00:00,  1.19it/s, loss=1.58, v_num=0, val_loss=1.430, val_acc=0.417, train_acc=0.248, test_loss=1.480, test_acc=0.440]
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.50it/s]average test f1 overlap @ 10%: 21.65329768270945
# average test f1 overlap @ 25%: 21.65329768270945
# average test f1 overlap @ 50%: 13.87551990493167
# average test edit: 17.71212121212121
# average test accuracy : 0.4746144711971283
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.50it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.4746144711971283
#         test_loss           1.4005610942840576
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁
# wandb:      average_val_edit ▁
# wandb:     average_val_f1_10 ▁
# wandb:     average_val_f1_25 ▁
# wandb:     average_val_f1_50 ▁
# wandb:            edit_score ▃▃▃▃▃▄▅▃▁▅▅▁▃▃▂▄▃▆▄▅▄▃▃▃▃▆▄▅▆▄▅▅▆██▇▅█▄▅
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         f1_overlap_10 ▂▁▃▂▃▃▃▃▁▄▄▁▁▄▂▂▃▂▂▂▁▂▂▃▃▄▂▂▄▃▃▄▃▄▅▅▃█▃▅
# wandb:         f1_overlap_25 ▂▁▁▂▂▂▃▂▁▄▄▁▁▁▂▂▃▂▂▂▁▁▂▂▃▂▂▂▄▂▃▄▃▄▃▃▃█▃▅
# wandb:         f1_overlap_50 ▁▁▁▂▂▁▄▁▁▄▁▁▁▁▄▂▁▄▂▁▁▁▁▂▁▄▂▄▇▃▅▇▃▇▁▅▁█▁▁
# wandb:         test_accuracy ▁▃█▃
# wandb:             test_loss ▇█▁▄
# wandb:        train_accuracy ▄▁▂▆▄▄▃▂▁▃▂▁▁▂▂▃▂▃▂▃▁▄▄▄▃▄▅▄▅█▆▆▅▇▅█▆█▃▆
# wandb:            train_loss ▄▆▆▄▅▅▅▅▅▅▅▅▅▅▅▄▅▅▅▄▅▄▄▄▅▄▄▃▃▃▁█▃▁▅▁▂▁▄▁
# wandb:          val_accuracy ▆▁▆█▅▆▄▂▆▃▃
# wandb:        val_edit_score █▃█▂▃▂▂▁▅▂▂
# wandb:     val_f1_overlap_10 █▄▆▃▄▃▁▁▃▃▂
# wandb:     val_f1_overlap_25 ▆█▄▅█▃▂▁▆▅▁
# wandb:     val_f1_overlap_50 ▁▁█▁▁▅▅▅▁▁▃
# wandb:              val_loss ▁▄▂▁▃▇██▅▄█
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.47461
# wandb:     average_test_edit 17.71212
# wandb:    average_test_f1_10 21.6533
# wandb:    average_test_f1_25 21.6533
# wandb:    average_test_f1_50 13.87552
# wandb:  average_val_accuracy 0.41695
# wandb:      average_val_edit 21.65368
# wandb:     average_val_f1_10 28.18352
# wandb:     average_val_f1_25 22.52695
# wandb:     average_val_f1_50 5.86028
# wandb:            edit_score 20.0
# wandb:                 epoch 0
# wandb:         f1_overlap_10 33.33333
# wandb:         f1_overlap_25 33.33333
# wandb:         f1_overlap_50 0.0
# wandb:         test_accuracy 0.41566
# wandb:             test_loss 1.34431
# wandb:        train_accuracy 0.41935
# wandb:            train_loss 1.2771
# wandb:          val_accuracy 0.35884
# wandb:        val_edit_score 16.66667
# wandb:     val_f1_overlap_10 17.14286
# wandb:     val_f1_overlap_25 11.42857
# wandb:     val_f1_overlap_50 5.71429
# wandb:              val_loss 1.57378
# wandb:
# wandb: Synced current_fold_1: https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_1
# wandb: Synced 5 W&B file(s), 59 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_191036-current_fold_1/logs
# STARTING FOLD 2
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_191131-current_fold_2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run current_fold_2
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_2
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1895: PossibleUserWarning: The number of training batches (44) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  73% 40/55 [00:40<00:15,  1.01s/it, loss=1.82, v_num=0, val_loss=1.430, val_acc=0.417, train_acc=0.248, test_loss=1.400, test_acc=0.475]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Epoch 0: 100% 55/55 [00:53<00:00,  1.03it/s, loss=1.81, v_num=0, val_loss=1.800, val_acc=0.120, train_acc=0.248, test_loss=1.400, test_acc=0.475]
# Epoch 0: 100% 55/55 [00:53<00:00,  1.03it/s, loss=1.81, v_num=0, val_loss=1.800, val_acc=0.120, train_acc=0.0956, test_loss=1.400, test_acc=0.475]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 55/55 [00:53<00:00,  1.03it/s, loss=1.81, v_num=0, val_loss=1.800, val_acc=0.120, train_acc=0.0956, test_loss=1.400, test_acc=0.475]
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.33it/s]average test f1 overlap @ 10%: 12.07092301025567
# average test f1 overlap @ 25%: 12.07092301025567
# average test f1 overlap @ 50%: 2.173913043478261
# average test edit: 19.44402910685805
# average test accuracy : 0.18456681072711945
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.33it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.18456681072711945
#         test_loss           1.7868483066558838
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁
# wandb:      average_val_edit ▁
# wandb:     average_val_f1_10 ▁
# wandb:     average_val_f1_25 ▁
# wandb:     average_val_f1_50 ▁
# wandb:            edit_score ▃▄▄▄▃▃▃▄█▄▆▁▃▄▄▃▃▆▃▅▄▅▁▄▄▃▄▆▂▄▁▄▁▅▄▅▄▅▄▄
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         f1_overlap_10 ▁▅▁▁▂▁▃▅▅▁▇▁▁▅▄▄▃▁▄▃▄▆▆▄▆▁▃▆▁▄▁▆▁▃█▄▃▅▃▄
# wandb:         f1_overlap_25 ▁▁▁▁▂▁▄▆▅▁█▁▁▅▅▃▄▁▅▃▃▄▇▃▅▁▄▄▁▁▁▄▁▃▅▅▄▃▄▁
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▂▆▁▁█▁▁▁▅▃▁▁▁▁▁▁▁▁▃▁▄▄▁▁▁▁▁▃▅▁▄▁▁▁
# wandb:         test_accuracy █▁▂▆
# wandb:             test_loss ▁█▆▃
# wandb:        train_accuracy ▁▃▁▁▇▁▆▃▃▁█▁▁▃▂▄▄▁▃▂▃▃▄▅▆▁▃▃▁▃▁▄▂▃▃▂▃▃▃▃
# wandb:            train_loss █▇▇▄▁▅▂▃▂▄▃▄▇▃▅▃▄▄▃▄▃▄▃▂▂▃▂▂▄▃▄▂▃▃▃▂▃▃▃▃
# wandb:          val_accuracy █▆▂▆▁▅▇▆▃▇▂
# wandb:        val_edit_score ▂▅▃▁▄▆▇▆▁█▂
# wandb:     val_f1_overlap_10 ▄▆▄▅▁▇▄▆▅█▄
# wandb:     val_f1_overlap_25 ▄▄▁▅▁▇▄▆▅█▁
# wandb:     val_f1_overlap_50 ▁▁▁▅▁█▃▅▁▁▁
# wandb:              val_loss ▂▃▅▁▅▅▂▅▃▃█
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.18457
# wandb:     average_test_edit 19.44403
# wandb:    average_test_f1_10 12.07092
# wandb:    average_test_f1_25 12.07092
# wandb:    average_test_f1_50 2.17391
# wandb:  average_val_accuracy 0.12038
# wandb:      average_val_edit 20.65996
# wandb:     average_val_f1_10 8.56113
# wandb:     average_val_f1_25 6.91611
# wandb:     average_val_f1_50 2.99129
# wandb:            edit_score 14.28571
# wandb:                 epoch 0
# wandb:         f1_overlap_10 10.52632
# wandb:         f1_overlap_25 0.0
# wandb:         f1_overlap_50 0.0
# wandb:         test_accuracy 0.23494
# wandb:             test_loss 1.77012
# wandb:        train_accuracy 0.08602
# wandb:            train_loss 1.82479
# wandb:          val_accuracy 0.05
# wandb:        val_edit_score 16.66667
# wandb:     val_f1_overlap_10 6.66667
# wandb:     val_f1_overlap_25 0.0
# wandb:     val_f1_overlap_50 0.0
# wandb:              val_loss 1.84853
# wandb:
# wandb: Synced current_fold_2: https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_2
# wandb: Synced 5 W&B file(s), 59 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_191131-current_fold_2/logs
# STARTING FOLD 3
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_191234-current_fold_3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run current_fold_3
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_3
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1895: PossibleUserWarning: The number of training batches (44) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  73% 40/55 [00:45<00:17,  1.14s/it, loss=1.81, v_num=0, val_loss=1.800, val_acc=0.120, train_acc=0.0956, test_loss=1.790, test_acc=0.185]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Epoch 0: 100% 55/55 [01:01<00:00,  1.12s/it, loss=1.8, v_num=0, val_loss=1.770, val_acc=0.160, train_acc=0.0956, test_loss=1.790, test_acc=0.185]
# Epoch 0: 100% 55/55 [01:01<00:00,  1.12s/it, loss=1.8, v_num=0, val_loss=1.770, val_acc=0.160, train_acc=0.130, test_loss=1.790, test_acc=0.185] `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 55/55 [01:01<00:00,  1.12s/it, loss=1.8, v_num=0, val_loss=1.770, val_acc=0.160, train_acc=0.130, test_loss=1.790, test_acc=0.185]
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.25it/s]average test f1 overlap @ 10%: 5.1163660382123535
# average test f1 overlap @ 25%: 1.836796145739235
# average test f1 overlap @ 50%: 0.0
# average test edit: 12.714285714285715
# average test accuracy : 0.11352311074733734
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.24it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.11352311074733734
#         test_loss            1.763850212097168
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁
# wandb:      average_val_edit ▁
# wandb:     average_val_f1_10 ▁
# wandb:     average_val_f1_25 ▁
# wandb:     average_val_f1_50 ▁
# wandb:            edit_score ▃▄▅▄▁▄▅▆▅▇▄▇█▁▁▅▅▅▅▅▅▃▅▄▅▅▂▂▃▃▅▃▄▅▃▅▄▄▃▅
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         f1_overlap_10 ▃▁▁▅▁▆▇▆▇▇▇█▇▁▁▁▆▅▅▄▇▄▅▅▆▇▄▃▃▅▁▂▄▅▄▃▃▅▂▄
# wandb:         f1_overlap_25 ▄▁▁▃▁▅█▇▇▅▇▅▇▁▁▁▇▆▅▁▄▄▆▅▄▇▂▁▃▅▁▁▂▆▁▃▃▄▂▁
# wandb:         f1_overlap_50 ▁▁▁▃▁▄█▁▇▁▄▁▁▁▁▁▁▆▁▁▁▁▆▂▁▁▁▁▁▁▁▁▁▄▁▁▁▄▁▁
# wandb:         test_accuracy ▁▃▄█
# wandb:             test_loss ▆█▇▁
# wandb:        train_accuracy ▅▁▁█▁▆▃▆▄▂▃▅▂▁▁▁▂▂▃▁▃▂▂▄▂▃▄▄▃▃▁▂▃▅▄▄▄▃▄▃
# wandb:            train_loss ▁█▄▂▅▃▄▃▃▅▆▅▃▅▄▆▄▄▄▅▃▄▄▄▄▄▄▃▃▃▄▃▃▃▂▄▄▄▂▃
# wandb:          val_accuracy ▄▁▅▃▅█▃▃▃▄▃
# wandb:        val_edit_score ▅▄▂█▃▇▃▁▃▅▆
# wandb:     val_f1_overlap_10 ▅▁▂█▄▇▃▃▄▅▄
# wandb:     val_f1_overlap_25 █▁▁▁▃▆▄▄▆█▆
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▅▁▁█
# wandb:              val_loss █▇▂▅▁▃▆▆█▅▅
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.11352
# wandb:     average_test_edit 12.71429
# wandb:    average_test_f1_10 5.11637
# wandb:    average_test_f1_25 1.8368
# wandb:    average_test_f1_50 0.0
# wandb:  average_val_accuracy 0.1598
# wandb:      average_val_edit 15.30673
# wandb:     average_val_f1_10 6.71568
# wandb:     average_val_f1_25 4.2363
# wandb:     average_val_f1_50 0.84422
# wandb:            edit_score 16.66667
# wandb:                 epoch 0
# wandb:         f1_overlap_10 8.69565
# wandb:         f1_overlap_25 0.0
# wandb:         f1_overlap_50 0.0
# wandb:         test_accuracy 0.1506
# wandb:             test_loss 1.74421
# wandb:        train_accuracy 0.09677
# wandb:            train_loss 1.80851
# wandb:          val_accuracy 0.10465
# wandb:        val_edit_score 20.0
# wandb:     val_f1_overlap_10 6.06061
# wandb:     val_f1_overlap_25 6.06061
# wandb:     val_f1_overlap_50 6.06061
# wandb:              val_loss 1.76364
# wandb:
# wandb: Synced current_fold_3: https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_3
# wandb: Synced 5 W&B file(s), 59 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_191234-current_fold_3/logs
# STARTING FOLD 4
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_191347-current_fold_4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run current_fold_4
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_4
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1895: PossibleUserWarning: The number of training batches (44) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  73% 40/55 [00:51<00:19,  1.29s/it, loss=1.79, v_num=0, val_loss=1.770, val_acc=0.160, train_acc=0.130, test_loss=1.760, test_acc=0.114]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Epoch 0: 100% 55/55 [01:07<00:00,  1.22s/it, loss=1.78, v_num=0, val_loss=1.720, val_acc=0.230, train_acc=0.130, test_loss=1.760, test_acc=0.114]
# Epoch 0: 100% 55/55 [01:07<00:00,  1.22s/it, loss=1.78, v_num=0, val_loss=1.720, val_acc=0.230, train_acc=0.128, test_loss=1.760, test_acc=0.114]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 55/55 [01:07<00:00,  1.22s/it, loss=1.78, v_num=0, val_loss=1.720, val_acc=0.230, train_acc=0.128, test_loss=1.760, test_acc=0.114]
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.11it/s]average test f1 overlap @ 10%: 3.605227091533211
# average test f1 overlap @ 25%: 3.605227091533211
# average test f1 overlap @ 50%: 2.420591456736035
# average test edit: 7.483405483405484
# average test accuracy : 0.23631824553012848
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.10it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.23631826043128967
#         test_loss           1.5937589406967163
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁
# wandb:      average_val_edit ▁
# wandb:     average_val_f1_10 ▁
# wandb:     average_val_f1_25 ▁
# wandb:     average_val_f1_50 ▁
# wandb:            edit_score ▃▄▄▅▅▄▅▄▅▆▄▄▁▁▄▃▄▇▄▇▃▃▃▅▂▃▄▂▂▂▂▃▄▆█▃▆▄▅▃
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         f1_overlap_10 ▃▁▅▁▁▅▁▇▇▇▆▅▁▁▅▅▆▁▃█▄▅▄▅▃▃▁▂▁▂▃▃▃▅█▂▃▅▃▂
# wandb:         f1_overlap_25 ▄▁▁▁▁▅▁█▁▇▆▅▁▁▆▃▁▁▄▅▂▅▃▁▂▂▁▁▁▁▁▁▄▅▅▂▃▆▃▁
# wandb:         f1_overlap_50 ▁▁▁▁▁▅▁█▁▄▁▁▁▁▁▁▁▁▄▁▁▄▁▁▁▁▁▁▁▁▁▁▁▃▁▁▁▁▃▁
# wandb:         test_accuracy ▁▂█▅
# wandb:             test_loss █▅▁▂
# wandb:        train_accuracy ▄▁▂▁▁█▁▃▅▂▃▂▁▁▂▄▂▁▄▃▅▅▃▂▄▅▂▄▂▁▃▄▄▃▅▅▄▄▃▄
# wandb:            train_loss ▁█▇▇▅▂▅▄▃▅▅▄▅▅▄▄▅▅▄▄▃▄▄▄▄▄▄▄▃▄▃▃▄▃▃▂▃▂▁▂
# wandb:          val_accuracy ▁█▁▃▇▅█▄▄▆▅
# wandb:        val_edit_score ▃█▃▁▃▂▅▆▇▅█
# wandb:     val_f1_overlap_10 ▁█▂▂▄▂▇▅█▃█
# wandb:     val_f1_overlap_25 ▂█▁▃▄▄▆▄▆▆▇
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁█▁█
# wandb:              val_loss ▂▁▅▄▂▅▂▃█▃▆
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.23632
# wandb:     average_test_edit 7.48341
# wandb:    average_test_f1_10 3.60523
# wandb:    average_test_f1_25 3.60523
# wandb:    average_test_f1_50 2.42059
# wandb:  average_val_accuracy 0.22995
# wandb:      average_val_edit 7.74553
# wandb:     average_val_f1_10 6.25388
# wandb:     average_val_f1_25 3.67607
# wandb:     average_val_f1_50 1.03981
# wandb:            edit_score 6.75676
# wandb:                 epoch 0
# wandb:         f1_overlap_10 2.5
# wandb:         f1_overlap_25 0.0
# wandb:         f1_overlap_50 0.0
# wandb:         test_accuracy 0.25904
# wandb:             test_loss 1.56303
# wandb:        train_accuracy 0.18824
# wandb:            train_loss 1.73694
# wandb:          val_accuracy 0.22581
# wandb:        val_edit_score 10.34483
# wandb:     val_f1_overlap_10 11.76471
# wandb:     val_f1_overlap_25 5.88235
# wandb:     val_f1_overlap_50 5.88235
# wandb:              val_loss 1.83563
# wandb:
# wandb: Synced current_fold_4: https://wandb.ai/soniamathews/TCN_KFOLD/runs/current_fold_4
# wandb: Synced 5 W&B file(s), 59 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_191347-current_fold_4/logs
# wandb: Tracking run with wandb version 0.13.0
# wandb: Run data is saved locally in /tmp/wandb/run-20220804_191507-1or5rncy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fresh-sun-7
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/TCN_KFOLD
# wandb: 🚀 View run at https://wandb.ai/soniamathews/TCN_KFOLD/runs/1or5rncy
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.61it/s]average test f1 overlap @ 10%: 11.080312722103766
# average test f1 overlap @ 25%: 6.881663113006397
# average test f1 overlap @ 50%: 5.389125799573561
# average test edit: 11.20169082125604
# average test accuracy : 0.4591529071331024
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.60it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.4591529071331024
#         test_loss           1.5281387567520142
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:              test_acc ▁▄█▅
# wandb:             test_loss ██▁▃
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.45915
# wandb:     average_test_edit 11.20169
# wandb:    average_test_f1_10 11.08031
# wandb:    average_test_f1_25 6.88166
# wandb:    average_test_f1_50 5.38913
# wandb:              test_acc 0.48193
# wandb:             test_loss 1.48819
# wandb:
# wandb: Synced fresh-sun-7: https://wandb.ai/soniamathews/TCN_KFOLD/runs/1or5rncy
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20220804_191507-1or5rncy/logs

# %%
! python main_2.py -f encoder_decoder_baseline.yaml

# %%
import numpy as np

# %%
results = np.load('inference_results/encoder_decoder_lstm/Encoder_Decoder_LSTM.npy')

# %%
results

# %%
type(results)
# Out:
# numpy.lib.npyio.NpzFile

# %%
list_obj = results.files

# %%
list_obj
# Out:
# ['archive/data.pkl',
#  'archive/data/0',
#  'archive/data/1',
#  'archive/data/2',
#  'archive/data/3',
#  'archive/data/4',
#  'archive/data/5',
#  'archive/data/6',
#  'archive/data/7',
#  'archive/data/8',
#  'archive/data/9',
#  'archive/version']

# %%
for item in list_obj[1:]:
    print(item)
    print(results[item])
    break
# Out:
# archive/data/0
# b'\x0e\x08\xdf;\xa0\x81_;J\x9c<=X7\x08=\x00\xed\xd7;\xbc^\xef=\xb2\xff\xbf<\xc0S\xb4:P\x03\xc4=\x84\x17\x90=\xfa\x167\xbdPG\xc9="\xbfq<\xe4#\xc4;\xe2Z\xe5=\r\xe9\xab=\x97\xdb\x9e\xbd3\x8f\xb5=\xdcb\xae\xbb\x16\xc3C<,\xe8\xaa=B\x02\x90=l\xdf~\xbdj\x04\xc1=\xd0M\xe99\xf0\xb6I<\xcd\xd8\xe0=\xe0\xca\xb2=\x15[\xb6\xbd8\xf4\xb5=\xe8\xb3T\xbc\x14 v<\xaa\xd4\xa8=V\xea\x92=\xc4<\x8f\xbd#p\xbe=J\xbbW\xbb\xd4\xa3^<\xecA\xdd=\x8ex\xb3=\xaa=\xc0\xbd\x7f\x8a\xb4=\xa6_s\xbcX\x16}<X\xf8\xa6=\'\xb4\x92=\xf4\x8d\x95\xbdWl\xbc=>\xc6\x87\xbbvs^<\xda\x03\xdb={\xd9\xb2=L\x05\xc4\xbd\xe1h\xb3=4\x98y\xbcH\\{<,\xc4\xa5=\x12\x04\x92=\xbb\xf5\x97\xbd\xf3O\xbb=\xf6\x9e\x8c\xbb\x96\xbe[<\xee\xd9\xd9=\xe8=\xb2=\xbck\xc5\xbd,\xcd\xb2=\xaaDz\xbcxiy<\xd8!\xa5=\x05\x83\x91=~\xdd\x98\xbd$\xd0\xba=%\xbe\x8c\xbb\x92\x07Z<\x89Q\xd9=[\xe0\xb1=\x9b\xef\xc5\xbdY\x89\xb2=r\xfdy\xbcB`x<\xe1\xd6\xa4="=\x91=Q4\x99\xbd\xfa\x9e\xba=\xc1D\x8c\xbbrCY<x\x18\xd9=\x97\xb2\xb1=\xdd\x1f\xc6\xbd)p\xb2=\x84\xb4y\xbc\x1c\xf4w<:\xb7\xa4=\x11\x1d\x91=fT\x99\xbd\xb4\x8e\xba=\x9e\xeb\x8b\xbb\x9c\xfcX<"\x02\xd9=\x08\x9f\xb1=31\xc6\xbd*h\xb2=>\x88y\xbc@\xd0w<\xa6\xaa\xa4=\x08\x10\x91=\xe1_\x99\xbdB\x8a\xba=A\xba\x8b\xbb\x1c\xe8X<\xc2\xf9\xd8=\x89\x97\xb1=27\xc6\xbd f\xb2=\xfapy\xbc2\xc7w<\xce\xa5\xa4=D\x0b\x91=\xc6c\x99\xbdm\x89\xba=p\xa1\x8b\xbbd\xe4X<\xac\xf6\xd8=\xf2\x94\xb1=\x1c9\xc6\xbd\xcfe\xb2=jey\xbc2\xc6w<\xf2\xa3\xa4=\xb3\t\x91=\xf8d\x99\xbdw\x89\xba=[\x95\x8b\xbb\xe8\xe4X<\x84\xf5\xd8=$\x94\xb1=\xa69\xc6\xbd\xdbe\xb2=\x06`y\xbc\xe2\xc6w<2\xa3\xa4=>\t\x91=He\x99\xbd\x98\x89\xba=\xd1\x8f\x8b\xbb\xc8\xe5X<\r\xf5\xd8=\xee\x93\xb1=\xc39\xc6\xbd\xf0e\xb2=t]y\xbc\x9a\xc7w<\xe4\xa2\xa4="\t\x91=Ue\x99\xbd\xb0\x89\xba=2\x8d\x8b\xbbn\xe6X<\xdb\xf4\xd8=\xe4\x93\xb1=\xc69\xc6\xbd\xfae\xb2=T\\y\xbc\x00\xc8w<\xbf\xa2\xa4=\x1e\t\x91=Se\x99\xbd\xba\x89\xba=\n\x8c\x8b\xbb\xb8\xe6X<\xc5\xf4\xd8=\xe2\x93\xb1=\xc29\xc6\xbd\xfee\xb2=\xcc[y\xbc,\xc8w<\xae\xa2\xa4=\x1e\t\x91=Oe\x99\xbd\xbe\x89\xba=u\x8b\x8b\xbb\xd2\xe6X<\xb8\xf4\xd8=\xe3\x93\xb1=\xbe9\xc6\xbd\x01f\xb2=\x96[y\xbc:\xc8w<\xa4\xa2\xa4= \t\x91=Me\x99\xbd\xbe\x89\xba=G\x8b\x8b\xbb\xe6\xe6X<\xb4\xf4\xd8=\xe2\x93\xb1=\xbb9\xc6\xbd\x01f\xb2=\x80[y\xbcL\xc8w<\xa2\xa2\xa4= \t\x91=Ke\x99\xbd\xbe\x89\xba=\r\x8b\x8b\xbb\xec\xe6X<\xb2\xf4\xd8=\xe4\x93\xb1=\xba9\xc6\xbd\x00f\xb2=d[y\xbcH\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\xeb\x8a\x8b\xbb\xe4\xe6X<\xaf\xf4\xd8=\xe5\x93\xb1=\xb99\xc6\xbd\x00f\xb2=h[y\xbcD\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\xf9\x8a\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x01f\xb2=p[y\xbcF\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe2\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcH\xc8w<\x9f\xa2\xa4= \t\x91=Ke\x99\xbd\xbf\x89\xba=\x01\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=l[y\xbcD\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x02\x8b\x8b\xbb\xe6\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=\\[y\xbcN\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x0b\x8b\x8b\xbb\xe8\xe6X<\xaf\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbc@\xc8w<\x9e\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe6\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcD\xc8w<\x9f\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe6\xe6X<\xb1\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xea\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xea\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=t[y\xbcF\xc8w<\x9f\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99 ...
