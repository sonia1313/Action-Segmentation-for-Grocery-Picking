# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/Othercomputers/Dell/Action-Segmentation-Project")
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/Othercomputers/Dell/Action-Segmentation-Project

# %%
! pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.7.1-py3-none-any.whl (701 kB)
#      |████████████████████████████████| 701 kB 13.9 MB/s
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.12.1+cu113)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 66.4 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.6)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 67.4 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.1.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.64.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 66.6 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 51.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.47.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (3.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.8.1)
# Installing collected packages: fsspec, torchmetrics, tensorboard, PyYAML, pyDeprecate, pytorch-lightning
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.10.0 which is incompatible.
# Successfully installed PyYAML-6.0 fsspec-2022.7.1 pyDeprecate-0.3.2 pytorch-lightning-1.7.1 tensorboard-2.10.0 torchmetrics-0.9.3

# %%
! pip install wandb -qU
# Out:
#      |████████████████████████████████| 1.8 MB 15.6 MB/s
#      |████████████████████████████████| 157 kB 59.7 MB/s
#      |████████████████████████████████| 181 kB 70.3 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#      |████████████████████████████████| 157 kB 73.6 MB/s
#      |████████████████████████████████| 157 kB 70.8 MB/s
#      |████████████████████████████████| 157 kB 68.1 MB/s
#      |████████████████████████████████| 156 kB 71.3 MB/s
#   Building wheel for pathtools (setup.py) ... done

# %%
# import main_2
# %load_ext autoreload
# %autoreload 2

# %%
! python cnn_tcn_lstm_kfold.py -f cnn_tcn_lstm_baseline.yaml
# Out:
# Global seed set to 42
# Tesla V100-SXM2-16GB
# no_sequences:30
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type             | Params
# ------------------------------------------------------
# 0 | cnn_tcn          | CNN_TCN          | 848 K
# 1 | lstm             | ManyToManyLSTM   | 115 K
# 2 | action_fc1       | Linear           | 906
# 3 | loss_module      | CrossEntropyLoss | 0
# 4 | train_acc        | Accuracy         | 0
# 5 | val_acc          | Accuracy         | 0
# 6 | test_acc         | Accuracy         | 0
# 7 | confusion_matrix | ConfusionMatrix  | 0
# ------------------------------------------------------
# 965 K     Trainable params
# 0         Non-trainable params
# 965 K     Total params
# 3.862     Total estimated model params size (MB)
# wandb: Currently logged in as: soniamathews. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_173050-3ogwungt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run restful-music-1
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3ogwungt
# STARTING FOLD 0
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:19<00:04,  1.02it/s, loss=1.72, v_num=12]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:23<00:00,  1.06it/s, loss=1.72, v_num=12, val_loss=1.580, val_acc=0.453]
# Epoch 1:  80% 20/25 [00:05<00:01,  3.70it/s, loss=1.56, v_num=12, val_loss=1.580, val_acc=0.453, train_acc=0.376]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:07<00:00,  3.23it/s, loss=1.56, v_num=12, val_loss=1.500, val_acc=0.453, train_acc=0.376]
# Epoch 2:  80% 20/25 [00:05<00:01,  3.72it/s, loss=1.49, v_num=12, val_loss=1.500, val_acc=0.453, train_acc=0.424]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:07<00:00,  3.28it/s, loss=1.49, v_num=12, val_loss=1.390, val_acc=0.493, train_acc=0.424]
# Epoch 3:  80% 20/25 [00:05<00:01,  3.75it/s, loss=1.42, v_num=12, val_loss=1.390, val_acc=0.493, train_acc=0.421]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:07<00:00,  3.14it/s, loss=1.42, v_num=12, val_loss=1.320, val_acc=0.485, train_acc=0.421]
# Epoch 4:  80% 20/25 [00:05<00:01,  3.73it/s, loss=1.37, v_num=12, val_loss=1.320, val_acc=0.485, train_acc=0.415]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:07<00:00,  3.32it/s, loss=1.37, v_num=12, val_loss=1.280, val_acc=0.413, train_acc=0.415]
# Epoch 5:  80% 20/25 [00:18<00:04,  1.10it/s, loss=1.33, v_num=12, val_loss=1.280, val_acc=0.413, train_acc=0.436]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:21<00:00,  1.14it/s, loss=1.33, v_num=12, val_loss=1.260, val_acc=0.438, train_acc=0.436]
# Epoch 6:  80% 20/25 [00:05<00:01,  3.60it/s, loss=1.29, v_num=12, val_loss=1.260, val_acc=0.438, train_acc=0.453]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:07<00:00,  3.22it/s, loss=1.29, v_num=12, val_loss=1.210, val_acc=0.491, train_acc=0.453]
# Epoch 7:  80% 20/25 [00:06<00:01,  3.13it/s, loss=1.22, v_num=12, val_loss=1.210, val_acc=0.491, train_acc=0.476]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:09<00:00,  2.71it/s, loss=1.22, v_num=12, val_loss=1.130, val_acc=0.563, train_acc=0.476]
# Epoch 8:  80% 20/25 [00:05<00:01,  3.71it/s, loss=1.12, v_num=12, val_loss=1.130, val_acc=0.563, train_acc=0.528]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:07<00:00,  3.21it/s, loss=1.12, v_num=12, val_loss=1.070, val_acc=0.587, train_acc=0.528]
# Epoch 9:  80% 20/25 [00:05<00:01,  3.74it/s, loss=1.04, v_num=12, val_loss=1.070, val_acc=0.587, train_acc=0.584]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:07<00:00,  3.28it/s, loss=1.04, v_num=12, val_loss=1.050, val_acc=0.592, train_acc=0.584]
# Epoch 9: 100% 25/25 [00:07<00:00,  3.27it/s, loss=1.04, v_num=12, val_loss=1.050, val_acc=0.592, train_acc=0.618]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:07<00:00,  3.19it/s, loss=1.04, v_num=12, val_loss=1.050, val_acc=0.592, train_acc=0.618]
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.18it/s]average test f1 overlap @ 10%: 58.90873337189127
# average test f1 overlap @ 25%: 56.803470213996526
# average test f1 overlap @ 50%: 25.86766917293233
# average test edit: 47.55594405594405
# average test accuracy : 0.577010452747345
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.17it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.5770103931427002
#         test_loss           1.1818281412124634
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▃▃▄▄▁▂▄▇██
# wandb:      average_val_edit ▁▁▄▆▆▆▆▇██
# wandb:     average_val_f1_10 ▁▁▃▃▃▃▄▇██
# wandb:     average_val_f1_25 ▁▁▄▄▄▄▄▆██
# wandb:     average_val_f1_50 ▁▁▅▆▆▅▆▇█▇
# wandb:            edit_score ▃▂▃▄▂▂▃▄▂▁█▄▁▂▃▂▁▂▂▂▁▂▂▂▁▂▃▂▁▂▂▃▁▃▂▅▂▄▂▂
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▄▅▆▄▄▅▆▂▂█▆▁▁▃▂▁▁▁▂▁▁▂▂▁▂▂▂▂▂▂▃▂▄▃▅▃▅▃▂
# wandb:         f1_overlap_25 ▂▁▁█▁▁▁█▂▁▅█▁▂▄▂▁▂▂▂▁▂▂▂▂▁▃▃▂▃▂▃▂▅▃▇▂▅▃▂
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▁▁▂▁▁▁▁▂▃▂▂▂▂▂▂▂▂▂▂▂▃▄▁▅▂▅▁▆▂▅▂█▄▃
# wandb:         test_accuracy ▂▁▁▃█
# wandb:             test_loss ▆█▅▂▁
# wandb:        train_accuracy ▁▆▆▄▇▆▆▄▆▆▆▄▆▃▅▆▆▄▅▆▆▄▅▇▇▅▆▇▆▆▆█▇▇▇█▇▇▇▅
# wandb:            train_loss ██▇█▅▅▆█▅▅▆▇▅▆▅▄▄▅▄▃▄▄▄▃▄▄▄▂▄▃▄▂▃▂▃▁▂▁▃▄
# wandb:          val_accuracy ▂▇▅▄▂▇▅▄▃▇▅▄▄▇▅▂▁▆▄▂▂▇▅▂▄▇▅▂▅█▆▅▆█▇▆▅█▆▇
# wandb:        val_edit_score ▁▁▁▁▁▁▁▁▄▃▁▆▆▄▆▆▇▃▆▆▄▆▆▆▄▆▆▆▇▆▆███▃█▅██▇
# wandb:     val_f1_overlap_10 ▁▂▂▂▁▂▂▂▃▄▂▁▃▃▁▁▂▄▁▁▃▃▁▁▃▄▁▃▅▇▃▇▅▇▃█▃▇▅▅
# wandb:     val_f1_overlap_25 ▁▄▄▁▁▄▄▁▅▅▄▃▃▅▃▃▂▅▃▃▂▅▃▃▄▆▃▃▅▇▅▆▅█▅▇▅█▆▅
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁▁▇▁▁▄▅▄▁▃▇▄▁▂▆▄▁▃▅▄▁▅▅▃▅▅█▄▇▄▆▆▄
# wandb:              val_loss █▆▇█▇▆▇▇▆▆▅▆▆▅▄▆▆▅▄▅▆▄▄▅▅▄▃▅▅▃▃▄▅▂▂▄▅▁▃▄
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.57701
# wandb:     average_test_edit 47.55594
# wandb:    average_test_f1_10 58.90873
# wandb:    average_test_f1_25 56.80347
# wandb:    average_test_f1_50 25.86767
# wandb:  average_val_accuracy 0.59197
# wandb:      average_val_edit 52.88711
# wandb:     average_val_f1_10 55.41809
# wandb:     average_val_f1_25 53.31283
# wandb:     average_val_f1_50 26.89451
# wandb:            edit_score 7.64331
# wandb:                 epoch 9
# wandb:         f1_overlap_10 7.05882
# wandb:         f1_overlap_25 5.88235
# wandb:         f1_overlap_50 4.70588
# wandb:         test_accuracy 0.81162
# wandb:             test_loss 0.88323
# wandb:        train_accuracy 0.43119
# wandb:            train_loss 1.32184
# wandb:          val_accuracy 0.59653
# wandb:        val_edit_score 54.54545
# wandb:     val_f1_overlap_10 52.63158
# wandb:     val_f1_overlap_25 42.10526
# wandb:     val_f1_overlap_50 21.05263
# wandb:              val_loss 1.13784
# wandb:
# wandb: Synced restful-music-1: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3ogwungt
# wandb: Synced 5 W&B file(s), 55 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_173050-3ogwungt/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_173253-35sos78d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hopeful-blaze-2
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/35sos78d
# STARTING FOLD 1
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:21<00:05,  1.07s/it, loss=1.76, v_num=12, val_loss=1.050, val_acc=0.592, train_acc=0.618, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:25<00:00,  1.03s/it, loss=1.76, v_num=12, val_loss=1.710, val_acc=0.403, train_acc=0.618, test_loss=1.180, test_acc=0.577]
# Epoch 1:  80% 20/25 [00:08<00:02,  2.33it/s, loss=1.63, v_num=12, val_loss=1.710, val_acc=0.403, train_acc=0.338, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:11<00:00,  2.16it/s, loss=1.63, v_num=12, val_loss=1.570, val_acc=0.403, train_acc=0.338, test_loss=1.180, test_acc=0.577]
# Epoch 2:  80% 20/25 [00:08<00:02,  2.34it/s, loss=1.54, v_num=12, val_loss=1.570, val_acc=0.403, train_acc=0.436, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:11<00:00,  2.24it/s, loss=1.54, v_num=12, val_loss=1.520, val_acc=0.403, train_acc=0.436, test_loss=1.180, test_acc=0.577]
# Epoch 3:  80% 20/25 [00:08<00:02,  2.39it/s, loss=1.48, v_num=12, val_loss=1.520, val_acc=0.403, train_acc=0.435, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:10<00:00,  2.28it/s, loss=1.48, v_num=12, val_loss=1.450, val_acc=0.403, train_acc=0.435, test_loss=1.180, test_acc=0.577]
# Epoch 4:  80% 20/25 [00:08<00:02,  2.29it/s, loss=1.43, v_num=12, val_loss=1.450, val_acc=0.403, train_acc=0.434, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:11<00:00,  2.17it/s, loss=1.43, v_num=12, val_loss=1.400, val_acc=0.405, train_acc=0.434, test_loss=1.180, test_acc=0.577]
# Epoch 5:  80% 20/25 [00:22<00:05,  1.14s/it, loss=1.4, v_num=12, val_loss=1.400, val_acc=0.405, train_acc=0.404, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:27<00:00,  1.09s/it, loss=1.4, v_num=12, val_loss=1.380, val_acc=0.409, train_acc=0.404, test_loss=1.180, test_acc=0.577]
# Epoch 6:  80% 20/25 [00:09<00:02,  2.18it/s, loss=1.38, v_num=12, val_loss=1.380, val_acc=0.409, train_acc=0.403, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:11<00:00,  2.12it/s, loss=1.38, v_num=12, val_loss=1.370, val_acc=0.403, train_acc=0.403, test_loss=1.180, test_acc=0.577]
# Epoch 7:  80% 20/25 [00:08<00:02,  2.30it/s, loss=1.36, v_num=12, val_loss=1.370, val_acc=0.403, train_acc=0.398, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:11<00:00,  2.19it/s, loss=1.36, v_num=12, val_loss=1.360, val_acc=0.433, train_acc=0.398, test_loss=1.180, test_acc=0.577]
# Epoch 8:  80% 20/25 [00:08<00:02,  2.26it/s, loss=1.34, v_num=12, val_loss=1.360, val_acc=0.433, train_acc=0.412, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:11<00:00,  2.17it/s, loss=1.34, v_num=12, val_loss=1.350, val_acc=0.423, train_acc=0.412, test_loss=1.180, test_acc=0.577]
# Epoch 9:  80% 20/25 [00:08<00:02,  2.25it/s, loss=1.32, v_num=12, val_loss=1.350, val_acc=0.423, train_acc=0.421, test_loss=1.180, test_acc=0.577]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:11<00:00,  2.16it/s, loss=1.32, v_num=12, val_loss=1.330, val_acc=0.448, train_acc=0.421, test_loss=1.180, test_acc=0.577]
# Epoch 9: 100% 25/25 [00:11<00:00,  2.16it/s, loss=1.32, v_num=12, val_loss=1.330, val_acc=0.448, train_acc=0.437, test_loss=1.180, test_acc=0.577]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:11<00:00,  2.14it/s, loss=1.32, v_num=12, val_loss=1.330, val_acc=0.448, train_acc=0.437, test_loss=1.180, test_acc=0.577]
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.11it/s]average test f1 overlap @ 10%: 38.16763696074041
# average test f1 overlap @ 25%: 29.883564711150918
# average test f1 overlap @ 50%: 14.593596059113299
# average test edit: 41.5
# average test accuracy : 0.4370640814304352
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.10it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.4370640814304352
#         test_loss           1.4140503406524658
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁▁▁▁▁▂▁▆▄█
# wandb:      average_val_edit ▁▁▁▁▃▃▄▇▆█
# wandb:     average_val_f1_10 ▃▃▃▃▃▄▁▆▆█
# wandb:     average_val_f1_25 ▃▃▃▃▇█▁▄▆▇
# wandb:     average_val_f1_50 ▁▁▁▁▁▁▁▆▅█
# wandb:            edit_score ▂▁▃▄▂▂▃▄▂▅▃▄▅▆█▇▁▁█▃▁▁█▃▁▁▂▃▁▁▂▂▁▁▃▂▁▁▂▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▂▇█▅▅▇█▅█▇█▅▆▆▄▂▁▅▃▁▁▅▃▁▂▃▃▁▂▃▂▁▂▃▂▁▂▃▁
# wandb:         f1_overlap_25 ▁▁▇█▁▅▇█▁▅▇█▅▆▆▄▁▁▅▃▁▁▅▃▁▁▃▃▁▁▂▂▁▂▃▂▁▂▃▁
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▁▁▁▆▁▁▁▅█▁▁▂▁▁▁▂▁▄▁▂▂▂▁▂▂▂▁▁▂▂▁▂▃▁
# wandb:         test_accuracy ▅▅▁▇█
# wandb:             test_loss ▅█▇▁▁
# wandb:        train_accuracy ▁▄█▅███▅███▅█▇█▆█▅█▆▇▅█▆▇▆▆▇▆▆▆▆▅▇▆▇▅▆▆▅
# wandb:            train_loss ▇▇▇▇▆▆▅█▃▄▄▇▃▄▃▃▂▄▃▂▂▄▂▁▂▃▃▁▃▃▃▁▃▂▃▁▃▃▂▄
# wandb:          val_accuracy ▃▆▂▁▃▆▂▁▃▆▂▁▃▆▂▁▁█▂▁▄▆▂▁▃▆▂▁▄▇▂▂▄▆▂▂▄█▂▄
# wandb:        val_edit_score ▁▁▁▂▁▁▁▂▁▁▁▂▁▁▁▂▃▆▁▂▃▄▁▂▃▄▁▂▆▅▁▄▆▄▁▄▄▆▁█
# wandb:     val_f1_overlap_10 ▂▃▃▄▂▃▃▄▂▃▃▄▂▃▃▄▂▄▃▄▄▃▃▄▂▂▃▄▆▆▃▁▅▄▃▃▄█▃▄
# wandb:     val_f1_overlap_25 ▁▆▁▆▁▆▁▆▁▆▁▆▁▆▁▆▄▇▁▆▇▅▁▆▁▅▁▆▆▆▁▃█▇▁▃▅█▁▇
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄▆▁▃▃▄▁▃▃█▁▄
# wandb:              val_loss █▇██▅▄▆▆▄▃▆▅▄▂▄▄▄▂▃▃▃▂▃▃▃▁▃▃▃▁▂▃▃▁▂▃▃▁▂▄
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.43706
# wandb:     average_test_edit 41.5
# wandb:    average_test_f1_10 38.16764
# wandb:    average_test_f1_25 29.88356
# wandb:    average_test_f1_50 14.5936
# wandb:  average_val_accuracy 0.44762
# wandb:      average_val_edit 36.66667
# wandb:     average_val_f1_10 33.88833
# wandb:     average_val_f1_25 20.72816
# wandb:     average_val_f1_50 15.42902
# wandb:            edit_score 3.08989
# wandb:                 epoch 9
# wandb:         f1_overlap_10 1.62602
# wandb:         f1_overlap_25 1.08401
# wandb:         f1_overlap_50 0.54201
# wandb:         test_accuracy 0.59969
# wandb:             test_loss 1.28142
# wandb:        train_accuracy 0.32824
# wandb:            train_loss 1.51503
# wandb:          val_accuracy 0.44041
# wandb:        val_edit_score 57.14286
# wandb:     val_f1_overlap_10 30.76923
# wandb:     val_f1_overlap_25 30.76923
# wandb:     val_f1_overlap_50 15.38462
# wandb:              val_loss 1.43155
# wandb:
# wandb: Synced hopeful-blaze-2: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/35sos78d
# wandb: Synced 5 W&B file(s), 55 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_173253-35sos78d/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_173533-17s4fyxu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mild-glade-3
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/17s4fyxu
# STARTING FOLD 2
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:25<00:06,  1.25s/it, loss=1.77, v_num=12, val_loss=1.330, val_acc=0.448, train_acc=0.437, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:29<00:00,  1.19s/it, loss=1.77, v_num=12, val_loss=1.720, val_acc=0.489, train_acc=0.437, test_loss=1.410, test_acc=0.437]
# Epoch 1:  80% 20/25 [00:12<00:03,  1.65it/s, loss=1.67, v_num=12, val_loss=1.720, val_acc=0.489, train_acc=0.312, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:15<00:00,  1.63it/s, loss=1.67, v_num=12, val_loss=1.570, val_acc=0.489, train_acc=0.312, test_loss=1.410, test_acc=0.437]
# Epoch 2:  80% 20/25 [00:13<00:03,  1.49it/s, loss=1.57, v_num=12, val_loss=1.570, val_acc=0.489, train_acc=0.414, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:16<00:00,  1.49it/s, loss=1.57, v_num=12, val_loss=1.530, val_acc=0.489, train_acc=0.414, test_loss=1.410, test_acc=0.437]
# Epoch 3:  80% 20/25 [00:12<00:03,  1.66it/s, loss=1.51, v_num=12, val_loss=1.530, val_acc=0.489, train_acc=0.415, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:15<00:00,  1.60it/s, loss=1.51, v_num=12, val_loss=1.470, val_acc=0.489, train_acc=0.415, test_loss=1.410, test_acc=0.437]
# Epoch 4:  80% 20/25 [00:12<00:03,  1.66it/s, loss=1.44, v_num=12, val_loss=1.470, val_acc=0.489, train_acc=0.409, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:15<00:00,  1.64it/s, loss=1.44, v_num=12, val_loss=1.450, val_acc=0.380, train_acc=0.409, test_loss=1.410, test_acc=0.437]
# Epoch 5:  80% 20/25 [00:24<00:06,  1.24s/it, loss=1.41, v_num=12, val_loss=1.450, val_acc=0.380, train_acc=0.412, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:29<00:00,  1.18s/it, loss=1.41, v_num=12, val_loss=1.410, val_acc=0.385, train_acc=0.412, test_loss=1.410, test_acc=0.437]
# Epoch 6:  80% 20/25 [00:12<00:03,  1.64it/s, loss=1.37, v_num=12, val_loss=1.410, val_acc=0.385, train_acc=0.400, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:15<00:00,  1.62it/s, loss=1.37, v_num=12, val_loss=1.410, val_acc=0.342, train_acc=0.400, test_loss=1.410, test_acc=0.437]
# Epoch 7:  80% 20/25 [00:12<00:03,  1.66it/s, loss=1.34, v_num=12, val_loss=1.410, val_acc=0.342, train_acc=0.420, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:15<00:00,  1.64it/s, loss=1.34, v_num=12, val_loss=1.390, val_acc=0.325, train_acc=0.420, test_loss=1.410, test_acc=0.437]
# Epoch 8:  80% 20/25 [00:12<00:03,  1.65it/s, loss=1.32, v_num=12, val_loss=1.390, val_acc=0.325, train_acc=0.444, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:15<00:00,  1.60it/s, loss=1.32, v_num=12, val_loss=1.380, val_acc=0.353, train_acc=0.444, test_loss=1.410, test_acc=0.437]
# Epoch 9:  80% 20/25 [00:13<00:03,  1.52it/s, loss=1.29, v_num=12, val_loss=1.380, val_acc=0.353, train_acc=0.454, test_loss=1.410, test_acc=0.437]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:16<00:00,  1.49it/s, loss=1.29, v_num=12, val_loss=1.360, val_acc=0.406, train_acc=0.454, test_loss=1.410, test_acc=0.437]
# Epoch 9: 100% 25/25 [00:16<00:00,  1.49it/s, loss=1.29, v_num=12, val_loss=1.360, val_acc=0.406, train_acc=0.473, test_loss=1.410, test_acc=0.437]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:16<00:00,  1.48it/s, loss=1.29, v_num=12, val_loss=1.360, val_acc=0.406, train_acc=0.473, test_loss=1.410, test_acc=0.437]
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.09it/s]average test f1 overlap @ 10%: 49.28037741412354
# average test f1 overlap @ 25%: 46.927436237652955
# average test f1 overlap @ 50%: 27.9359575409111
# average test edit: 44.15584415584416
# average test accuracy : 0.49574407935142517
# Testing DataLoader 0: 100% 5/5 [00:04<00:00,  1.09it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.49574413895606995
#         test_loss           1.3960297107696533
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ████▃▄▂▁▂▄
# wandb:      average_val_edit ▁▁▁▁▆▅▆▆▇█
# wandb:     average_val_f1_10 ▁▁▁▁▂▆▄▆▇█
# wandb:     average_val_f1_25 ▁▁▁▁▄▆▆▆▅█
# wandb:     average_val_f1_50 ▁▁▁▁█▆▃▃▆▄
# wandb:            edit_score ▄▁▃▃▃▃▃▃▃▃▃▆▃▂█▆▁▂█▂▁▁▂▂▁▂▁▃▂▂▂▂▂▂▂▃▂▂▁▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▂▇█▆▇▇█▆▇▇▆▄▃▅▄▂▃▅▂▂▂▃▃▂▃▂▃▂▂▂▃▂▂▂▅▂▂▂▂
# wandb:         f1_overlap_25 ▁▁▁█▁▇▁█▁▇▁▆▄▂▅▄▁▂▅▂▂▂▃▂▂▃▂▃▂▂▂▃▂▂▂▂▂▂▁▂
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁█▄▁▁▁▁▂▁▂▁▂▃▂▁▂▁▃▂▂▂▂▂▂▂▃▂▂▂▁
# wandb:         test_accuracy ▃▁▁▃█
# wandb:             test_loss ▄█▄▁▁
# wandb:        train_accuracy ▁▇▅▅▅█▅▅▅█▅▅▅▆▅▅▅▅▅▅▆▄▅▅▆▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅
# wandb:            train_loss ███▇▇▆▆▆▄▂▅▅▃▄▄▇▂▄▄▆▂▄▃▆▁▂▂▆▃▂▂▆▃▁▁▅▂▁▁▃
# wandb:          val_accuracy ▅▂▃█▅▂▃█▅▂▃█▅▂▃█▂▂▃▄▄▂▂▃▃▂▁▂▃▁▁▂▃▁▂▄▃▂▃▅
# wandb:        val_edit_score ▁▂▁▂▁▂▁▂▁▂▁▂▁▂▁▂▄▃▆▅▄▃▆▂▄▃▆▂▄▅▆▂▇▅▆▃█▇▄▅
# wandb:     val_f1_overlap_10 ▁▂▂▄▁▂▂▄▁▂▂▄▁▂▂▄▅▂▃▂▇▂█▂▇▂▃▂▇▃█▂▆▄▇▄▇▄▅▇
# wandb:     val_f1_overlap_25 ▁▁▁▅▁▁▁▅▁▁▁▅▁▁▁▅▃▄▅▄▆▄▅▄▆▄▃▄▆▅▅▄▆▃▄▅▇▅▂█
# wandb:     val_f1_overlap_50 ▁▁▁█▁▁▁█▁▁▁█▁▁▁█▄▁▇▆▄▁▄▆▄▁▄▁▄▄▁▁▆▅▁▅▃▅▃▅
# wandb:              val_loss ▇█▇▇▅█▆▅▅█▅▄▄█▄▃▄▇▅▃▄▇▅▂▄█▅▂▄█▅▂▄█▅▂▄▇▄▁
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.49574
# wandb:     average_test_edit 44.15584
# wandb:    average_test_f1_10 49.28038
# wandb:    average_test_f1_25 46.92744
# wandb:    average_test_f1_50 27.93596
# wandb:  average_val_accuracy 0.40595
# wandb:      average_val_edit 45.71429
# wandb:     average_val_f1_10 43.35354
# wandb:     average_val_f1_25 35.13131
# wandb:     average_val_f1_50 11.19192
# wandb:            edit_score 4.31655
# wandb:                 epoch 9
# wandb:         f1_overlap_10 3.43643
# wandb:         f1_overlap_25 2.74914
# wandb:         f1_overlap_50 0.68729
# wandb:         test_accuracy 0.6248
# wandb:             test_loss 1.24282
# wandb:        train_accuracy 0.3945
# wandb:            train_loss 1.48821
# wandb:          val_accuracy 0.51955
# wandb:        val_edit_score 42.85714
# wandb:     val_f1_overlap_10 54.54545
# wandb:     val_f1_overlap_25 54.54545
# wandb:     val_f1_overlap_50 18.18182
# wandb:              val_loss 1.11274
# wandb:
# wandb: Synced mild-glade-3: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/17s4fyxu
# wandb: Synced 5 W&B file(s), 55 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_173533-17s4fyxu/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_173853-3ei2aprf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lunar-butterfly-4
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3ei2aprf
# STARTING FOLD 3
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:29<00:07,  1.46s/it, loss=1.77, v_num=12, val_loss=1.360, val_acc=0.406, train_acc=0.473, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:34<00:00,  1.38s/it, loss=1.77, v_num=12, val_loss=1.740, val_acc=0.370, train_acc=0.473, test_loss=1.400, test_acc=0.496]
# Epoch 1:  80% 20/25 [00:15<00:03,  1.28it/s, loss=1.7, v_num=12, val_loss=1.740, val_acc=0.370, train_acc=0.351, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:19<00:00,  1.27it/s, loss=1.7, v_num=12, val_loss=1.670, val_acc=0.370, train_acc=0.351, test_loss=1.400, test_acc=0.496]
# Epoch 2:  80% 20/25 [00:15<00:03,  1.31it/s, loss=1.62, v_num=12, val_loss=1.670, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:19<00:00,  1.31it/s, loss=1.62, v_num=12, val_loss=1.600, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Epoch 3:  80% 20/25 [00:15<00:03,  1.29it/s, loss=1.54, v_num=12, val_loss=1.600, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:19<00:00,  1.29it/s, loss=1.54, v_num=12, val_loss=1.530, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Epoch 4:  80% 20/25 [00:15<00:03,  1.28it/s, loss=1.49, v_num=12, val_loss=1.530, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:20<00:00,  1.23it/s, loss=1.49, v_num=12, val_loss=1.480, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Epoch 5:  80% 20/25 [00:28<00:07,  1.45s/it, loss=1.42, v_num=12, val_loss=1.480, val_acc=0.370, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:34<00:00,  1.38s/it, loss=1.42, v_num=12, val_loss=1.430, val_acc=0.393, train_acc=0.444, test_loss=1.400, test_acc=0.496]
# Epoch 6:  80% 20/25 [00:15<00:03,  1.29it/s, loss=1.4, v_num=12, val_loss=1.430, val_acc=0.393, train_acc=0.446, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:19<00:00,  1.27it/s, loss=1.4, v_num=12, val_loss=1.420, val_acc=0.370, train_acc=0.446, test_loss=1.400, test_acc=0.496]
# Epoch 7:  80% 20/25 [00:15<00:03,  1.28it/s, loss=1.35, v_num=12, val_loss=1.420, val_acc=0.370, train_acc=0.425, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:19<00:00,  1.28it/s, loss=1.35, v_num=12, val_loss=1.390, val_acc=0.371, train_acc=0.425, test_loss=1.400, test_acc=0.496]
# Epoch 8:  80% 20/25 [00:15<00:03,  1.28it/s, loss=1.29, v_num=12, val_loss=1.390, val_acc=0.371, train_acc=0.450, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:19<00:00,  1.28it/s, loss=1.29, v_num=12, val_loss=1.350, val_acc=0.411, train_acc=0.450, test_loss=1.400, test_acc=0.496]
# Epoch 9:  80% 20/25 [00:15<00:03,  1.31it/s, loss=1.24, v_num=12, val_loss=1.350, val_acc=0.411, train_acc=0.483, test_loss=1.400, test_acc=0.496]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:19<00:00,  1.30it/s, loss=1.24, v_num=12, val_loss=1.330, val_acc=0.420, train_acc=0.483, test_loss=1.400, test_acc=0.496]
# Epoch 9: 100% 25/25 [00:19<00:00,  1.30it/s, loss=1.24, v_num=12, val_loss=1.330, val_acc=0.420, train_acc=0.523, test_loss=1.400, test_acc=0.496]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:19<00:00,  1.29it/s, loss=1.24, v_num=12, val_loss=1.330, val_acc=0.420, train_acc=0.523, test_loss=1.400, test_acc=0.496]
# Testing DataLoader 0: 100% 5/5 [00:05<00:00,  1.08s/it]average test f1 overlap @ 10%: 44.03256003256003
# average test f1 overlap @ 25%: 38.16589336589336
# average test f1 overlap @ 50%: 20.816280016280015
# average test edit: 41.659147869674186
# average test accuracy : 0.43012571334838867
# Testing DataLoader 0: 100% 5/5 [00:05<00:00,  1.08s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.43012571334838867
#         test_loss           1.3539166450500488
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁▁▁▁▁▄▁▁▇█
# wandb:      average_val_edit ▁▁▁▁▁▇▁▂▇█
# wandb:     average_val_f1_10 ▁▁▁▁▁▆▁▁██
# wandb:     average_val_f1_25 ▁▁▁▁▁▆▁▁█▇
# wandb:     average_val_f1_50 ▁▁▁▁▁▇▁▃██
# wandb:            edit_score ▃▁▃▃▃▃▃▃▃▃▃▃▃▂▃▄▃▅▃▄▃▁█▆▁▁▅▄▂▁▁▁▂▁▁▂▂▂▁▂
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▁▇▇▆▇▇▇▆▇▇▇▆▅▇█▆█▇█▆▂▅▄▁▁▄█▂▂▁▂▃▂▁▂▃▂▂▂
# wandb:         f1_overlap_25 ▁▁▇▇▁▇▇▇▁▇▇▇▁▅▇█▁▅▇█▁▂▅▄▁▁▄█▂▁▁▂▂▁▁▂▂▂▁▂
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▂▁▁▁▁▆▁▁▁▂▂▁▁▂▂▂▁▂▂
# wandb:         test_accuracy ▃▅▁█▆
# wandb:             test_loss ▇▆█▁▄
# wandb:        train_accuracy ▁▅▇▇▅▇▇▇▅▇▇▇▅▇▇▄▅▇▇▄▅▆▇▄▆▅▅▄▅▆▆▄▅▆▇▅▅▆█▆
# wandb:            train_loss ███▇▇▇▇▇▆▆▆▅▅▅▅█▄▅▄▇▃▄▂▅▃▄▃▅▅▄▂▄▅▃▂▃▄▃▁▂
# wandb:          val_accuracy ▄▁▄▄▄▁▄▄▄▁▄▄▄▁▄▄▄▁▄▄▃▃█▅▄▁▄▄▄▁▄▄▅▄█▄▅▄█▅
# wandb:        val_edit_score ▁▁▂▂▁▁▂▂▁▁▂▂▁▁▂▂▁▁▂▂▅▇▅▆▁▁▂▂▁▁▅▂▇▇▅▅▇█▆▄
# wandb:     val_f1_overlap_10 ▁▂▅▃▁▂▅▃▁▂▅▃▁▂▅▃▁▂▅▃▅▅█▃▁▂▅▃▁▂▃▃█▇▆▅█▆▅▆
# wandb:     val_f1_overlap_25 ▁▁▆▁▁▁▆▁▁▁▆▁▁▁▆▁▁▁▆▁▅▆█▃▁▁▆▁▁▁▅▁█▇▇▆█▆▆▅
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▇▁█▁▁▁▁▁▁▁█▁▆▄▇▆▆▄▆▆
# wandb:              val_loss ████▇▇▇▇▆▇▆▆▆▆▅▅▅▅▄▄▅▄▃▃▄▅▃▂▃▄▂▂▃▄▁▁▃▄▁▄
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.43013
# wandb:     average_test_edit 41.65915
# wandb:    average_test_f1_10 44.03256
# wandb:    average_test_f1_25 38.16589
# wandb:    average_test_f1_50 20.81628
# wandb:  average_val_accuracy 0.42027
# wandb:      average_val_edit 46.08263
# wandb:     average_val_f1_10 34.98171
# wandb:     average_val_f1_25 31.76534
# wandb:     average_val_f1_50 13.21761
# wandb:            edit_score 7.44681
# wandb:                 epoch 9
# wandb:         f1_overlap_10 5.88235
# wandb:         f1_overlap_25 3.92157
# wandb:         f1_overlap_50 1.96078
# wandb:         test_accuracy 0.50863
# wandb:             test_loss 1.24161
# wandb:        train_accuracy 0.45987
# wandb:            train_loss 1.24994
# wandb:          val_accuracy 0.40163
# wandb:        val_edit_score 30.43478
# wandb:     val_f1_overlap_10 33.33333
# wandb:     val_f1_overlap_25 27.77778
# wandb:     val_f1_overlap_50 16.66667
# wandb:              val_loss 1.45666
# wandb:
# wandb: Synced lunar-butterfly-4: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3ei2aprf
# wandb: Synced 5 W&B file(s), 55 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_173853-3ei2aprf/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_174254-3sebg5dt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deep-voice-5
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3sebg5dt
# STARTING FOLD 4
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:33<00:08,  1.66s/it, loss=1.77, v_num=12, val_loss=1.330, val_acc=0.420, train_acc=0.523, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:39<00:00,  1.57s/it, loss=1.77, v_num=12, val_loss=1.740, val_acc=0.432, train_acc=0.523, test_loss=1.350, test_acc=0.430]
# Epoch 1:  80% 20/25 [00:18<00:04,  1.08it/s, loss=1.7, v_num=12, val_loss=1.740, val_acc=0.432, train_acc=0.326, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:23<00:00,  1.06it/s, loss=1.7, v_num=12, val_loss=1.660, val_acc=0.432, train_acc=0.326, test_loss=1.350, test_acc=0.430]
# Epoch 2:  80% 20/25 [00:20<00:05,  1.01s/it, loss=1.61, v_num=12, val_loss=1.660, val_acc=0.432, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:25<00:00,  1.01s/it, loss=1.61, v_num=12, val_loss=1.560, val_acc=0.432, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Epoch 3:  80% 20/25 [00:18<00:04,  1.08it/s, loss=1.52, v_num=12, val_loss=1.560, val_acc=0.432, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:23<00:00,  1.07it/s, loss=1.52, v_num=12, val_loss=1.510, val_acc=0.432, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Epoch 4:  80% 20/25 [00:18<00:04,  1.09it/s, loss=1.45, v_num=12, val_loss=1.510, val_acc=0.432, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:23<00:00,  1.08it/s, loss=1.45, v_num=12, val_loss=1.440, val_acc=0.394, train_acc=0.429, test_loss=1.350, test_acc=0.430]
# Epoch 5:  80% 20/25 [00:34<00:08,  1.70s/it, loss=1.4, v_num=12, val_loss=1.440, val_acc=0.394, train_acc=0.425, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:40<00:00,  1.60s/it, loss=1.4, v_num=12, val_loss=1.410, val_acc=0.351, train_acc=0.425, test_loss=1.350, test_acc=0.430]
# Epoch 6:  80% 20/25 [00:20<00:05,  1.01s/it, loss=1.37, v_num=12, val_loss=1.410, val_acc=0.351, train_acc=0.415, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:24<00:00,  1.00it/s, loss=1.37, v_num=12, val_loss=1.390, val_acc=0.371, train_acc=0.415, test_loss=1.350, test_acc=0.430]
# Epoch 7:  80% 20/25 [00:18<00:04,  1.08it/s, loss=1.32, v_num=12, val_loss=1.390, val_acc=0.371, train_acc=0.422, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:23<00:00,  1.07it/s, loss=1.32, v_num=12, val_loss=1.380, val_acc=0.372, train_acc=0.422, test_loss=1.350, test_acc=0.430]
# Epoch 8:  80% 20/25 [00:18<00:04,  1.07it/s, loss=1.29, v_num=12, val_loss=1.380, val_acc=0.372, train_acc=0.456, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:24<00:00,  1.04it/s, loss=1.29, v_num=12, val_loss=1.370, val_acc=0.384, train_acc=0.456, test_loss=1.350, test_acc=0.430]
# Epoch 9:  80% 20/25 [00:18<00:04,  1.09it/s, loss=1.23, v_num=12, val_loss=1.370, val_acc=0.384, train_acc=0.470, test_loss=1.350, test_acc=0.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:23<00:00,  1.08it/s, loss=1.23, v_num=12, val_loss=1.350, val_acc=0.450, train_acc=0.470, test_loss=1.350, test_acc=0.430]
# Epoch 9: 100% 25/25 [00:23<00:00,  1.08it/s, loss=1.23, v_num=12, val_loss=1.350, val_acc=0.450, train_acc=0.506, test_loss=1.350, test_acc=0.430]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:23<00:00,  1.07it/s, loss=1.23, v_num=12, val_loss=1.350, val_acc=0.450, train_acc=0.506, test_loss=1.350, test_acc=0.430]
# Testing DataLoader 0: 100% 5/5 [00:06<00:00,  1.36s/it]average test f1 overlap @ 10%: 46.173669467787114
# average test f1 overlap @ 25%: 41.09430438842203
# average test f1 overlap @ 50%: 16.138188608776844
# average test edit: 43.90909090909091
# average test accuracy : 0.5045755505561829
# Testing DataLoader 0: 100% 5/5 [00:06<00:00,  1.36s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.5045755505561829
#         test_loss           1.3585221767425537
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▇▇▇▇▄▁▂▂▃█
# wandb:      average_val_edit ▁▁▁▁▇▆▇▇██
# wandb:     average_val_f1_10 ▁▁▁▁▆▅▄▆▆█
# wandb:     average_val_f1_25 ▁▁▁▁▆▅▅▇▇█
# wandb:     average_val_f1_50 ▁▁▁▁▅▇▆███
# wandb:            edit_score ▃▁▃▄▃▃▃▄▃▃▃▄▃▃▃▃▂▁█▆▁▂█▃▁▂▄▃▆▂▃▃▆▂▃▂▃▂▂▂
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▁▇█▆▇▇█▆▇▇█▆▆▇▇▂▂▆▄▁▂▅▂▂▂▃▂▃▂▃▂▄▁▃▄▄▂▃▃
# wandb:         f1_overlap_25 ▁▁▇█▁▇▇█▁▇▇█▁▁▇▇▂▁▆▄▁▂▅▂▁▂▂▂▃▂▃▂▄▁▃▄▄▁▃▂
# wandb:         f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▃▁▁▂▃▁▁▂▃▁▁▁▃▄▁▁▃▄█▆▃▄▂
# wandb:         test_accuracy ▃▁▁▃█
# wandb:             test_loss ▆█▇▄▁
# wandb:        train_accuracy ▁▄█▆▆██▆▆██▆▆▆█▆▇▅█▆█▄█▆▇▄▆▆▅▄▇▆▅▄▇▇▅▅▇▆
# wandb:            train_loss ██▇█▇▇▆▇▆▅▅▆▄▅▄▇▂▅▃▆▂▄▁▅▂▄▂▅▅▃▂▃▅▃▂▂▃▂▁▄
# wandb:          val_accuracy ▆▇▆▆▆▇▆▆▆▇▆▆▆▇▆▆▅█▂▃▅▇▁▁▆▇▂▁▆█▁▁▇█▁▂▇█▅▅
# wandb:        val_edit_score ▁▁▂▂▁▁▂▂▁▁▂▂▁▁▂▂▆▅▆▆▄▅▆▆▇▅▆▆█▅▆▆█▅▆▇▇▅▇▇
# wandb:     val_f1_overlap_10 ▁▁▂▂▁▁▂▂▁▁▂▂▁▁▂▂▇▇▁▄▆▇▁▂▄▅▂▁▇▇▂▂▆▇▂▃▅▇▄█
# wandb:     val_f1_overlap_25 ▁▄▁▁▁▄▁▁▁▄▁▁▁▄▁▁▇▇▃▃▆▅▃▄▄▇▄▃█▇▄▄█▇▄▅▇▇▅▇
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄▅▁▁▇▅▅▁▄▅▆▁▆█▆▁▆█▆▁▇█▄▇
# wandb:              val_loss ████▆▆▇▇▄▅▅▅▃▄▅▄▃▃▄▃▄▃▃▂▃▂▃▂▃▂▄▂▃▂▄▂▂▁▄▁
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.50458
# wandb:     average_test_edit 43.90909
# wandb:    average_test_f1_10 46.17367
# wandb:    average_test_f1_25 41.0943
# wandb:    average_test_f1_50 16.13819
# wandb:  average_val_accuracy 0.44999
# wandb:      average_val_edit 43.39239
# wandb:     average_val_f1_10 43.4178
# wandb:     average_val_f1_25 32.34263
# wandb:     average_val_f1_50 15.96833
# wandb:            edit_score 6.59341
# wandb:                 epoch 9
# wandb:         f1_overlap_10 7.17949
# wandb:         f1_overlap_25 4.10256
# wandb:         f1_overlap_50 1.02564
# wandb:         test_accuracy 0.65934
# wandb:             test_loss 1.18272
# wandb:        train_accuracy 0.41794
# wandb:            train_loss 1.48208
# wandb:          val_accuracy 0.40767
# wandb:        val_edit_score 50.0
# wandb:     val_f1_overlap_10 60.0
# wandb:     val_f1_overlap_25 40.0
# wandb:     val_f1_overlap_50 20.0
# wandb:              val_loss 1.29512
# wandb:
# wandb: Synced deep-voice-5: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/3sebg5dt
# wandb: Synced 5 W&B file(s), 55 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_174254-3sebg5dt/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220814_174743-et0kwoic
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lucky-dew-6
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/et0kwoic
# Testing DataLoader 0: 100% 5/5 [00:03<00:00,  1.35it/s]average test f1 overlap @ 10%: 55.335221044939715
# average test f1 overlap @ 25%: 49.504018998903916
# average test f1 overlap @ 50%: 23.50200949945195
# average test edit: 45.12121212121211
# average test accuracy : 0.5437821745872498
# Testing DataLoader 0: 100% 5/5 [00:03<00:00,  1.35it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     ensemble_test_acc        0.543782114982605
#    ensemble_test_loss       1.2898954153060913
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: e_average_test_accuracy ▁
# wandb:     e_average_test_edit ▁
# wandb:    e_average_test_f1_10 ▁
# wandb:    e_average_test_f1_25 ▁
# wandb:    e_average_test_f1_50 ▁
# wandb:             e_test_loss ▆█▇▁▂
# wandb:                test_acc ▂▂▁▆█
# wandb:
# wandb: Run summary:
# wandb: e_average_test_accuracy 0.54378
# wandb:     e_average_test_edit 45.12121
# wandb:    e_average_test_f1_10 55.33522
# wandb:    e_average_test_f1_25 49.50402
# wandb:    e_average_test_f1_50 23.50201
# wandb:             e_test_loss 1.12356
# wandb:                test_acc 0.75039
# wandb:
# wandb: Synced lucky-dew-6: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Clutter_Report/runs/et0kwoic
# wandb: Synced 5 W&B file(s), 5 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220814_174743-et0kwoic/logs

# %%
! python main_2.py -f encoder_decoder_baseline.yaml

# %%
import numpy as np

# %%
results = np.load('inference_results/encoder_decoder_lstm/Encoder_Decoder_LSTM.npy')

# %%
results

# %%
type(results)
# Out:
# numpy.lib.npyio.NpzFile

# %%
list_obj = results.files

# %%
list_obj
# Out:
# ['archive/data.pkl',
#  'archive/data/0',
#  'archive/data/1',
#  'archive/data/2',
#  'archive/data/3',
#  'archive/data/4',
#  'archive/data/5',
#  'archive/data/6',
#  'archive/data/7',
#  'archive/data/8',
#  'archive/data/9',
#  'archive/version']

# %%
for item in list_obj[1:]:
    print(item)
    print(results[item])
    break
# Out:
# archive/data/0
# b'\x0e\x08\xdf;\xa0\x81_;J\x9c<=X7\x08=\x00\xed\xd7;\xbc^\xef=\xb2\xff\xbf<\xc0S\xb4:P\x03\xc4=\x84\x17\x90=\xfa\x167\xbdPG\xc9="\xbfq<\xe4#\xc4;\xe2Z\xe5=\r\xe9\xab=\x97\xdb\x9e\xbd3\x8f\xb5=\xdcb\xae\xbb\x16\xc3C<,\xe8\xaa=B\x02\x90=l\xdf~\xbdj\x04\xc1=\xd0M\xe99\xf0\xb6I<\xcd\xd8\xe0=\xe0\xca\xb2=\x15[\xb6\xbd8\xf4\xb5=\xe8\xb3T\xbc\x14 v<\xaa\xd4\xa8=V\xea\x92=\xc4<\x8f\xbd#p\xbe=J\xbbW\xbb\xd4\xa3^<\xecA\xdd=\x8ex\xb3=\xaa=\xc0\xbd\x7f\x8a\xb4=\xa6_s\xbcX\x16}<X\xf8\xa6=\'\xb4\x92=\xf4\x8d\x95\xbdWl\xbc=>\xc6\x87\xbbvs^<\xda\x03\xdb={\xd9\xb2=L\x05\xc4\xbd\xe1h\xb3=4\x98y\xbcH\\{<,\xc4\xa5=\x12\x04\x92=\xbb\xf5\x97\xbd\xf3O\xbb=\xf6\x9e\x8c\xbb\x96\xbe[<\xee\xd9\xd9=\xe8=\xb2=\xbck\xc5\xbd,\xcd\xb2=\xaaDz\xbcxiy<\xd8!\xa5=\x05\x83\x91=~\xdd\x98\xbd$\xd0\xba=%\xbe\x8c\xbb\x92\x07Z<\x89Q\xd9=[\xe0\xb1=\x9b\xef\xc5\xbdY\x89\xb2=r\xfdy\xbcB`x<\xe1\xd6\xa4="=\x91=Q4\x99\xbd\xfa\x9e\xba=\xc1D\x8c\xbbrCY<x\x18\xd9=\x97\xb2\xb1=\xdd\x1f\xc6\xbd)p\xb2=\x84\xb4y\xbc\x1c\xf4w<:\xb7\xa4=\x11\x1d\x91=fT\x99\xbd\xb4\x8e\xba=\x9e\xeb\x8b\xbb\x9c\xfcX<"\x02\xd9=\x08\x9f\xb1=31\xc6\xbd*h\xb2=>\x88y\xbc@\xd0w<\xa6\xaa\xa4=\x08\x10\x91=\xe1_\x99\xbdB\x8a\xba=A\xba\x8b\xbb\x1c\xe8X<\xc2\xf9\xd8=\x89\x97\xb1=27\xc6\xbd f\xb2=\xfapy\xbc2\xc7w<\xce\xa5\xa4=D\x0b\x91=\xc6c\x99\xbdm\x89\xba=p\xa1\x8b\xbbd\xe4X<\xac\xf6\xd8=\xf2\x94\xb1=\x1c9\xc6\xbd\xcfe\xb2=jey\xbc2\xc6w<\xf2\xa3\xa4=\xb3\t\x91=\xf8d\x99\xbdw\x89\xba=[\x95\x8b\xbb\xe8\xe4X<\x84\xf5\xd8=$\x94\xb1=\xa69\xc6\xbd\xdbe\xb2=\x06`y\xbc\xe2\xc6w<2\xa3\xa4=>\t\x91=He\x99\xbd\x98\x89\xba=\xd1\x8f\x8b\xbb\xc8\xe5X<\r\xf5\xd8=\xee\x93\xb1=\xc39\xc6\xbd\xf0e\xb2=t]y\xbc\x9a\xc7w<\xe4\xa2\xa4="\t\x91=Ue\x99\xbd\xb0\x89\xba=2\x8d\x8b\xbbn\xe6X<\xdb\xf4\xd8=\xe4\x93\xb1=\xc69\xc6\xbd\xfae\xb2=T\\y\xbc\x00\xc8w<\xbf\xa2\xa4=\x1e\t\x91=Se\x99\xbd\xba\x89\xba=\n\x8c\x8b\xbb\xb8\xe6X<\xc5\xf4\xd8=\xe2\x93\xb1=\xc29\xc6\xbd\xfee\xb2=\xcc[y\xbc,\xc8w<\xae\xa2\xa4=\x1e\t\x91=Oe\x99\xbd\xbe\x89\xba=u\x8b\x8b\xbb\xd2\xe6X<\xb8\xf4\xd8=\xe3\x93\xb1=\xbe9\xc6\xbd\x01f\xb2=\x96[y\xbc:\xc8w<\xa4\xa2\xa4= \t\x91=Me\x99\xbd\xbe\x89\xba=G\x8b\x8b\xbb\xe6\xe6X<\xb4\xf4\xd8=\xe2\x93\xb1=\xbb9\xc6\xbd\x01f\xb2=\x80[y\xbcL\xc8w<\xa2\xa2\xa4= \t\x91=Ke\x99\xbd\xbe\x89\xba=\r\x8b\x8b\xbb\xec\xe6X<\xb2\xf4\xd8=\xe4\x93\xb1=\xba9\xc6\xbd\x00f\xb2=d[y\xbcH\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\xeb\x8a\x8b\xbb\xe4\xe6X<\xaf\xf4\xd8=\xe5\x93\xb1=\xb99\xc6\xbd\x00f\xb2=h[y\xbcD\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\xf9\x8a\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x01f\xb2=p[y\xbcF\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe2\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcH\xc8w<\x9f\xa2\xa4= \t\x91=Ke\x99\xbd\xbf\x89\xba=\x01\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=l[y\xbcD\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x02\x8b\x8b\xbb\xe6\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=\\[y\xbcN\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x0b\x8b\x8b\xbb\xe8\xe6X<\xaf\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbc@\xc8w<\x9e\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe6\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcD\xc8w<\x9f\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe6\xe6X<\xb1\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\x9f\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xea\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\x9e\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\x01\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe4\x93\xb1=\xb99\xc6\xbd\x00f\xb2=p[y\xbcF\xc8w<\xa0\xa2\xa4= \t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xea\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99\xc6\xbd\x00f\xb2=t[y\xbcF\xc8w<\x9f\xa2\xa4=!\t\x91=Je\x99\xbd\xbe\x89\xba=\t\x8b\x8b\xbb\xe8\xe6X<\xb0\xf4\xd8=\xe6\x93\xb1=\xb99 ...
