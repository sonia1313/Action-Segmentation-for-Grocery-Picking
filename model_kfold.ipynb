# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/Othercomputers/Dell/Action-Segmentation-Project")
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/Othercomputers/Dell/Action-Segmentation-Project

# %%
! pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 701 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 141 kB 65.5 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 59.3 MB/s
# ...
#      |████████████████████████████████| 419 kB 67.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.5 MB/s
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
! pip install wandb -qU
# Out:
#      |████████████████████████████████| 1.8 MB 4.3 MB/s
#      |████████████████████████████████| 181 kB 66.4 MB/s
#      |████████████████████████████████| 157 kB 69.7 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
#      |████████████████████████████████| 157 kB 68.3 MB/s
#      |████████████████████████████████| 157 kB 66.6 MB/s
#      |████████████████████████████████| 157 kB 65.7 MB/s
#      |████████████████████████████████| 156 kB 66.4 MB/s
# ...

# %%
# import main_2
# %load_ext autoreload
# %autoreload 2

# %%
! python cnn_tcn_lstm_kfold.py -f cnn_tcn_lstm_baseline.yaml
# Out:
# Global seed set to 42
# Tesla V100-SXM2-16GB
# no_sequences:30
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logging/testing_hidden_1/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type             | Params
# ------------------------------------------------------
# 0 | cnn_tcn          | CNN_TCN          | 848 K
# 1 | lstm             | ManyToManyLSTM   | 13.6 K
# 2 | action_fc1       | Linear           | 606
# 3 | loss_module      | CrossEntropyLoss | 0
# ...

# %%
! python main_2.py -f encoder_decoder_baseline.yaml

# %%
import numpy as np

# %%
results = np.load('inference_results/encoder_decoder_lstm/Encoder_Decoder_LSTM.npy')

# %%
results

# %%
type(results)
# Out:
# numpy.lib.npyio.NpzFile

# %%
list_obj = results.files

# %%
list_obj
# Out:
# ['archive/data.pkl',
#  'archive/data/0',
#  'archive/data/1',
#  'archive/data/2',
#  'archive/data/3',
#  'archive/data/4',
#  'archive/data/5',
#  'archive/data/6',
#  'archive/data/7',
#  'archive/data/8',
#  'archive/data/9',
#  'archive/version']

# %%
for item in list_obj[1:]:
    print(item)
    print(results[item])
    break
# Out:
# archive/data/0
# ...
