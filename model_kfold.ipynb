# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

os.chdir("TODO")
# Out:
# Mounted at /content/drive

# %%
! pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.7.2-py3-none-any.whl (705 kB)
#      |████████████████████████████████| 705 kB 15.6 MB/s
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.1.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2.9.1)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 72.3 MB/s
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 71.3 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.6)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 62.2 MB/s
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.2.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.47.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.4.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (3.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Installing collected packages: fsspec, torchmetrics, PyYAML, pyDeprecate, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 fsspec-2022.7.1 pyDeprecate-0.3.2 pytorch-lightning-1.7.2 torchmetrics-0.9.3

# %%
! pip install wandb -qU
# Out:
#      |████████████████████████████████| 1.8 MB 14.6 MB/s
#      |████████████████████████████████| 181 kB 59.7 MB/s
#      |████████████████████████████████| 157 kB 73.1 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
#      |████████████████████████████████| 157 kB 73.7 MB/s
#      |████████████████████████████████| 157 kB 74.9 MB/s
#      |████████████████████████████████| 157 kB 80.2 MB/s
#      |████████████████████████████████| 157 kB 68.1 MB/s
#      |████████████████████████████████| 156 kB 69.1 MB/s
#   Building wheel for pathtools (setup.py) ... done

# %%
# import main_2
# %load_ext autoreload
# %autoreload 2

# %%
! python cnn_tcn_lstm_kfold.py -f cnn_tcn_lstm_baseline.yaml
# Out:
# Global seed set to 42
# Tesla V100-SXM2-16GB
# no_sequences:29
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:447: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type             | Params
# -------------------------------------------------------
# 0 | cnn_tcn           | CNN_TCN          | 848 K
# 1 | lstm              | ManyToManyLSTM   | 115 K
# 2 | action_fc1        | Linear           | 906
# 3 | fruits_fc1        | Linear           | 453
# 4 | loss_module       | CrossEntropyLoss | 0
# 5 | fruit_loss_module | CrossEntropyLoss | 0
# 6 | train_acc         | Accuracy         | 0
# 7 | val_acc           | Accuracy         | 0
# 8 | test_acc          | Accuracy         | 0
# 9 | confusion_matrix  | ConfusionMatrix  | 0
# -------------------------------------------------------
# 965 K     Trainable params
# 0         Non-trainable params
# 965 K     Total params
# 3.864     Total estimated model params size (MB)
# wandb: Currently logged in as: soniamathews. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_140513-3l7k18z0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run chocolate-terrain-4
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/3l7k18z0
# STARTING FOLD 0
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:20<00:05,  1.02s/it, loss=2.86, v_num=3]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:24<00:00,  1.04it/s, loss=2.86, v_num=3, val_loss=2.740, val_acc=0.472]
# Epoch 1:  80% 20/25 [00:04<00:01,  4.10it/s, loss=2.68, v_num=3, val_loss=2.740, val_acc=0.472, train_acc=0.353]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:06<00:00,  3.57it/s, loss=2.68, v_num=3, val_loss=2.590, val_acc=0.472, train_acc=0.353]
# Epoch 2:  80% 20/25 [00:04<00:01,  4.18it/s, loss=2.47, v_num=3, val_loss=2.590, val_acc=0.472, train_acc=0.419]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:06<00:00,  3.59it/s, loss=2.47, v_num=3, val_loss=2.510, val_acc=0.439, train_acc=0.419]
# Epoch 3:  80% 20/25 [00:04<00:01,  4.26it/s, loss=2.33, v_num=3, val_loss=2.510, val_acc=0.439, train_acc=0.450]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:07<00:00,  3.56it/s, loss=2.33, v_num=3, val_loss=2.370, val_acc=0.502, train_acc=0.450]
# Epoch 4:  80% 20/25 [00:04<00:01,  4.18it/s, loss=2.24, v_num=3, val_loss=2.370, val_acc=0.502, train_acc=0.486]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:06<00:00,  3.60it/s, loss=2.24, v_num=3, val_loss=2.230, val_acc=0.563, train_acc=0.486]
# Epoch 5:  80% 20/25 [00:16<00:04,  1.21it/s, loss=2.15, v_num=3, val_loss=2.230, val_acc=0.563, train_acc=0.503]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:20<00:00,  1.24it/s, loss=2.15, v_num=3, val_loss=2.230, val_acc=0.553, train_acc=0.503]
# Epoch 6:  80% 20/25 [00:04<00:01,  4.12it/s, loss=2.06, v_num=3, val_loss=2.230, val_acc=0.553, train_acc=0.523]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:07<00:00,  3.56it/s, loss=2.06, v_num=3, val_loss=2.130, val_acc=0.582, train_acc=0.523]
# Epoch 7:  80% 20/25 [00:04<00:01,  4.17it/s, loss=1.96, v_num=3, val_loss=2.130, val_acc=0.582, train_acc=0.536]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:06<00:00,  3.59it/s, loss=1.96, v_num=3, val_loss=2.170, val_acc=0.590, train_acc=0.536]
# Epoch 8:  80% 20/25 [00:04<00:01,  4.20it/s, loss=1.84, v_num=3, val_loss=2.170, val_acc=0.590, train_acc=0.562]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:07<00:00,  3.51it/s, loss=1.84, v_num=3, val_loss=2.210, val_acc=0.611, train_acc=0.562]
# Epoch 9:  80% 20/25 [00:04<00:01,  4.22it/s, loss=1.65, v_num=3, val_loss=2.210, val_acc=0.611, train_acc=0.584]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:06<00:00,  3.67it/s, loss=1.65, v_num=3, val_loss=2.100, val_acc=0.612, train_acc=0.584]
# Epoch 9: 100% 25/25 [00:06<00:00,  3.67it/s, loss=1.65, v_num=3, val_loss=2.100, val_acc=0.612, train_acc=0.631]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:07<00:00,  3.56it/s, loss=1.65, v_num=3, val_loss=2.100, val_acc=0.612, train_acc=0.631]
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.46it/s]average test f1 overlap @ 10%: 66.66666666666667
# average test f1 overlap @ 25%: 66.66666666666667
# average test f1 overlap @ 50%: 47.222222222222214
# average test edit: 63.86363636363637
# average test accuracy : 0.6112304329872131
# Testing DataLoader 0: 100% 4/4 [00:02<00:00,  1.46it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.6112304329872131
#         test_loss            2.767244338989258
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▂▂▁▄▆▆▇▇██
# wandb:      average_val_edit ▁▁▄▆▆▆████
# wandb:     average_val_f1_10 ▁▁▅▆▆▆▇▇▇█
# wandb:     average_val_f1_25 ▂▂▁▅▆▅▇▇▇█
# wandb:     average_val_f1_50 ▁▁▅▅▇▇▇█▆▇
# wandb:            edit_score ▇▄▇▇▇▇▇▇█▇▅▆▁▂▃▅▁▂▄▄▁▂▃▄▁▂▂▄▁▂▂▆▂▂▂▅▂▂▂▂
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▃██████▄█▃▃▂▂▃▄▁▃▃▂▂▂▃▂▂▂▂▃▂▂▂▃▂▃▂▄▃▃▂▂
# wandb:         f1_overlap_25 ▁▃██████▄█▃▃▁▁▃▂▁▂▃▂▁▂▂▂▂▁▂▂▁▁▂▃▂▂▂▂▂▂▂▂
# wandb:         f1_overlap_50 ▁▃▁▁█▁▁▁▄▁▃▃▁▁▂▁▁▂▂▂▁▁▂▂▁▁▁▂▁▁▁▂▂▂▂▂▁▂▂▂
# wandb:         test_accuracy █▁▃█
# wandb:             test_loss ▁▂█▂
# wandb:        train_accuracy ▁▅▄▅▆▅▄▅▆▅▄▅▆▇▅▄▅▇▆▄▅▇▆▄▅▇▅▄▇▇▅▅▇█▅▅██▆▆
# wandb:            train_loss ██▇█▇▇▇▇▇▆▆▆▇▅▆▇▆▅▅▇▅▅▄▇▆▅▆▆▄▅▅▆▃▅▅▇▃▃▄▁
# wandb:          val_accuracy ▃▄▄▃▃▄▄▃▄▁▄▃▇▁▅▄█▁▅▅█▁▄▅█▁▆▅█▁▆▆▇▁▇▇▇▁▇▅
# wandb:        val_edit_score ▂▁▂▂▂▁▂▂▄▂▄▄▆▂▆▆█▂▆▅█▂▆▆█▂███▅█▇█▅█▇█▄█▅
# wandb:     val_f1_overlap_10 ▂▁▂▂▂▁▂▂▅▃▅▅▆▃▇▆█▂▅▄█▁▅▇█▂▇▅█▃▇▆█▃▇▆█▃█▄
# wandb:     val_f1_overlap_25 ▂▁▂▂▂▁▂▂▂▁▂▂▆▁▇▆█▂▅▅█▂▅▄█▂▇▅█▃▇▅█▃▇▅█▃█▃
# wandb:     val_f1_overlap_50 ▁▁▄▁▁▁▄▁▃▃▃▃▆▃▃▃█▂▄▂▆▂▄▅▆▂▄▄▆▃▆▄▅▃▄▄▅▃▅▄
# wandb:              val_loss ██▇█▇▇▆▇▆▆▆▇▅▅▆▆▄▄▅▄▄▃▆▄▄▃▅▃▅▃▆▂▆▂▆▁▆▂▆▇
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.61123
# wandb:     average_test_edit 63.86364
# wandb:    average_test_f1_10 66.66667
# wandb:    average_test_f1_25 66.66667
# wandb:    average_test_f1_50 47.22222
# wandb:  average_val_accuracy 0.61156
# wandb:      average_val_edit 66.33333
# wandb:     average_val_f1_10 72.24242
# wandb:     average_val_f1_25 68.60606
# wandb:     average_val_f1_50 37.93939
# wandb:            edit_score 5.42636
# wandb:                 epoch 9
# wandb:         f1_overlap_10 5.7971
# wandb:         f1_overlap_25 4.34783
# wandb:         f1_overlap_50 2.89855
# wandb:         test_accuracy 0.86532
# wandb:             test_loss 2.1068
# wandb:        train_accuracy 0.5674
# wandb:            train_loss 1.20869
# wandb:          val_accuracy 0.56089
# wandb:        val_edit_score 50.0
# wandb:     val_f1_overlap_10 54.54545
# wandb:     val_f1_overlap_25 36.36364
# wandb:     val_f1_overlap_50 36.36364
# wandb:              val_loss 2.69257
# wandb:
# wandb: Synced chocolate-terrain-4: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/3l7k18z0
# wandb: Synced 5 W&B file(s), 54 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_140513-3l7k18z0/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_140705-2by1eqm9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fine-field-5
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/2by1eqm9
# STARTING FOLD 1
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:20<00:05,  1.04s/it, loss=2.88, v_num=3, val_loss=2.100, val_acc=0.612, train_acc=0.631, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:24<00:00,  1.00it/s, loss=2.88, v_num=3, val_loss=2.850, val_acc=0.424, train_acc=0.631, test_loss=2.770, test_acc=0.611]
# Epoch 1:  80% 20/25 [00:08<00:02,  2.40it/s, loss=2.79, v_num=3, val_loss=2.850, val_acc=0.424, train_acc=0.282, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:10<00:00,  2.29it/s, loss=2.79, v_num=3, val_loss=2.830, val_acc=0.424, train_acc=0.282, test_loss=2.770, test_acc=0.611]
# Epoch 2:  80% 20/25 [00:07<00:01,  2.50it/s, loss=2.62, v_num=3, val_loss=2.830, val_acc=0.424, train_acc=0.431, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:10<00:00,  2.30it/s, loss=2.62, v_num=3, val_loss=2.890, val_acc=0.424, train_acc=0.431, test_loss=2.770, test_acc=0.611]
# Epoch 3:  80% 20/25 [00:09<00:02,  2.04it/s, loss=2.42, v_num=3, val_loss=2.890, val_acc=0.424, train_acc=0.431, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:12<00:00,  2.02it/s, loss=2.42, v_num=3, val_loss=3.000, val_acc=0.449, train_acc=0.431, test_loss=2.770, test_acc=0.611]
# Epoch 4:  80% 20/25 [00:08<00:02,  2.48it/s, loss=2.36, v_num=3, val_loss=3.000, val_acc=0.449, train_acc=0.442, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:10<00:00,  2.33it/s, loss=2.36, v_num=3, val_loss=2.690, val_acc=0.478, train_acc=0.442, test_loss=2.770, test_acc=0.611]
# Epoch 5:  80% 20/25 [00:20<00:05,  1.02s/it, loss=2.21, v_num=3, val_loss=2.690, val_acc=0.478, train_acc=0.470, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:24<00:00,  1.02it/s, loss=2.21, v_num=3, val_loss=2.620, val_acc=0.541, train_acc=0.470, test_loss=2.770, test_acc=0.611]
# Epoch 6:  80% 20/25 [00:08<00:02,  2.44it/s, loss=2.2, v_num=3, val_loss=2.620, val_acc=0.541, train_acc=0.486, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:10<00:00,  2.31it/s, loss=2.2, v_num=3, val_loss=2.510, val_acc=0.511, train_acc=0.486, test_loss=2.770, test_acc=0.611]
# Epoch 7:  80% 20/25 [00:08<00:02,  2.46it/s, loss=2.12, v_num=3, val_loss=2.510, val_acc=0.511, train_acc=0.493, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:10<00:00,  2.28it/s, loss=2.12, v_num=3, val_loss=2.430, val_acc=0.535, train_acc=0.493, test_loss=2.770, test_acc=0.611]
# Epoch 8:  80% 20/25 [00:08<00:02,  2.48it/s, loss=2.04, v_num=3, val_loss=2.430, val_acc=0.535, train_acc=0.496, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:10<00:00,  2.36it/s, loss=2.04, v_num=3, val_loss=2.450, val_acc=0.534, train_acc=0.496, test_loss=2.770, test_acc=0.611]
# Epoch 9:  80% 20/25 [00:08<00:02,  2.47it/s, loss=1.99, v_num=3, val_loss=2.450, val_acc=0.534, train_acc=0.503, test_loss=2.770, test_acc=0.611]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:10<00:00,  2.34it/s, loss=1.99, v_num=3, val_loss=2.400, val_acc=0.550, train_acc=0.503, test_loss=2.770, test_acc=0.611]
# Epoch 9: 100% 25/25 [00:10<00:00,  2.34it/s, loss=1.99, v_num=3, val_loss=2.400, val_acc=0.550, train_acc=0.491, test_loss=2.770, test_acc=0.611]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:10<00:00,  2.32it/s, loss=1.99, v_num=3, val_loss=2.400, val_acc=0.550, train_acc=0.491, test_loss=2.770, test_acc=0.611]
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.25it/s]average test f1 overlap @ 10%: 46.80555555555556
# average test f1 overlap @ 25%: 37.08333333333333
# average test f1 overlap @ 50%: 33.75
# average test edit: 51.875
# average test accuracy : 0.481517493724823
# Testing DataLoader 0: 100% 4/4 [00:03<00:00,  1.24it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc             0.481517493724823
#         test_loss            2.684981346130371
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁▁▁▂▄█▆▇▇█
# wandb:      average_val_edit ▁▁▁▅▅▆▆▇▆█
# wandb:     average_val_f1_10 ▁▁▁▁▅█▆▇█▇
# wandb:     average_val_f1_25 ▃▃▃▁▃▆▅███
# wandb:     average_val_f1_50 ▁▁▁▃▆▆█▇▆▇
# wandb:            edit_score ▄▄▂█▄▄▄▄▄▄▄▄▄▅▁▄▁▂▁▂▁▂▁▃▁▂▁▂▁▂▁▂▁▂▁▂▁▂▁▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 ▁▁▂▆█████████▃▂▃▂▂▂▂▂▃▂▂▂▃▃▂▂▃▂▂▂▂▂▂▂▃▂▂
# wandb:         f1_overlap_25 ▁▁▂▆█████████▃▂▃▁▁▁▂▁▁▁▂▂▂▁▂▁▂▁▂▂▂▁▂▁▁▁▁
# wandb:         f1_overlap_50 ▁▁▂▆██▁▁██▁▁█▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁
# wandb:         test_accuracy ▄▁▂█
# wandb:             test_loss ▂▂█▁
# wandb:        train_accuracy ▁▁▆▅▇▆▅▅▇▆▅▅▇▄▆▄▇▅▇▄▇▅█▄▆▆▇▄█▆▆▄█▆▇▄▇▆▆▅
# wandb:            train_loss ████▇▇▇▇▆▆▆▇▅▆▄▆▅▅▄▇▃▆▄▆▃▆▇▇▂▅▇▆▂▅▅▆▁▅▅▂
# wandb:          val_accuracy ▂▁▃▅▂▁▃▅▂▁▃▅▂▁▄▅▃▁▅▅▃▃█▅▂▁█▅▂▂█▅▃▂█▅▄▂█▅
# wandb:        val_edit_score ▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▆▃▃▃▆▃▃▆▆▃▃▃▆▃▆▃█▆
# wandb:     val_f1_overlap_10 ▂▂▂▂▂▂▂▂▂▂▂▂▁▁▅▁▅▁▅▁▅▄█▁▁▁█▁▁▅█▁▅▄█▁▃▄▇█
# wandb:     val_f1_overlap_25 ▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▅▁▁▄█▁▁▁█▁▁▅█▁▁▄█▁▃▄▇█
# wandb:     val_f1_overlap_50 ▁▁▁▆▁▁▁▆▁▁▁▆▁▁▅▅▅▅▅▅▅▄█▅▅▅█▅▅▅█▅▅▄█▅▇▄▇▅
# wandb:              val_loss ▆▆▆▆▆▆▆▆▇▇▆▆██▇▇▆▆▆▅▆▆▆▄▅▅▅▄▄▅▅▃▄▅▆▃▄▄▆▁
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.48152
# wandb:     average_test_edit 51.875
# wandb:    average_test_f1_10 46.80556
# wandb:    average_test_f1_25 37.08333
# wandb:    average_test_f1_50 33.75
# wandb:  average_val_accuracy 0.54969
# wandb:      average_val_edit 56.0
# wandb:     average_val_f1_10 50.93651
# wandb:     average_val_f1_25 50.93651
# wandb:     average_val_f1_50 32.04762
# wandb:            edit_score 3.49345
# wandb:                 epoch 9
# wandb:         f1_overlap_10 2.52101
# wandb:         f1_overlap_25 1.68067
# wandb:         f1_overlap_50 0.84034
# wandb:         test_accuracy 0.74747
# wandb:             test_loss 1.61312
# wandb:        train_accuracy 0.37827
# wandb:            train_loss 1.63155
# wandb:          val_accuracy 0.5814
# wandb:        val_edit_score 60.0
# wandb:     val_f1_overlap_10 75.0
# wandb:     val_f1_overlap_25 75.0
# wandb:     val_f1_overlap_50 25.0
# wandb:              val_loss 1.87085
# wandb:
# wandb: Synced fine-field-5: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/2by1eqm9
# wandb: Synced 5 W&B file(s), 54 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_140705-2by1eqm9/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_140937-1jsq2mdk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run bright-sound-6
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/1jsq2mdk
# STARTING FOLD 2
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:24<00:06,  1.21s/it, loss=2.88, v_num=3, val_loss=2.400, val_acc=0.550, train_acc=0.491, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:28<00:00,  1.15s/it, loss=2.88, v_num=3, val_loss=2.840, val_acc=0.473, train_acc=0.491, test_loss=2.680, test_acc=0.482]
# Epoch 1:  80% 20/25 [00:11<00:02,  1.73it/s, loss=2.78, v_num=3, val_loss=2.840, val_acc=0.473, train_acc=0.250, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:15<00:00,  1.61it/s, loss=2.78, v_num=3, val_loss=2.710, val_acc=0.473, train_acc=0.250, test_loss=2.680, test_acc=0.482]
# Epoch 2:  80% 20/25 [00:12<00:03,  1.61it/s, loss=2.65, v_num=3, val_loss=2.710, val_acc=0.473, train_acc=0.419, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:15<00:00,  1.59it/s, loss=2.65, v_num=3, val_loss=2.570, val_acc=0.473, train_acc=0.419, test_loss=2.680, test_acc=0.482]
# Epoch 3:  80% 20/25 [00:11<00:02,  1.75it/s, loss=2.5, v_num=3, val_loss=2.570, val_acc=0.473, train_acc=0.419, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:14<00:00,  1.73it/s, loss=2.5, v_num=3, val_loss=2.490, val_acc=0.515, train_acc=0.419, test_loss=2.680, test_acc=0.482]
# Epoch 4:  80% 20/25 [00:11<00:02,  1.74it/s, loss=2.39, v_num=3, val_loss=2.490, val_acc=0.515, train_acc=0.434, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:14<00:00,  1.72it/s, loss=2.39, v_num=3, val_loss=2.370, val_acc=0.446, train_acc=0.434, test_loss=2.680, test_acc=0.482]
# Epoch 5:  80% 20/25 [00:24<00:06,  1.20s/it, loss=2.23, v_num=3, val_loss=2.370, val_acc=0.446, train_acc=0.489, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:28<00:00,  1.15s/it, loss=2.23, v_num=3, val_loss=2.320, val_acc=0.448, train_acc=0.489, test_loss=2.680, test_acc=0.482]
# Epoch 6:  80% 20/25 [00:11<00:02,  1.70it/s, loss=2.22, v_num=3, val_loss=2.320, val_acc=0.448, train_acc=0.505, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:15<00:00,  1.65it/s, loss=2.22, v_num=3, val_loss=2.310, val_acc=0.427, train_acc=0.505, test_loss=2.680, test_acc=0.482]
# Epoch 7:  80% 20/25 [00:11<00:02,  1.72it/s, loss=2.1, v_num=3, val_loss=2.310, val_acc=0.427, train_acc=0.516, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:14<00:00,  1.70it/s, loss=2.1, v_num=3, val_loss=2.250, val_acc=0.405, train_acc=0.516, test_loss=2.680, test_acc=0.482]
# Epoch 8:  80% 20/25 [00:11<00:02,  1.73it/s, loss=2.09, v_num=3, val_loss=2.250, val_acc=0.405, train_acc=0.520, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:14<00:00,  1.71it/s, loss=2.09, v_num=3, val_loss=2.200, val_acc=0.409, train_acc=0.520, test_loss=2.680, test_acc=0.482]
# Epoch 9:  80% 20/25 [00:11<00:02,  1.73it/s, loss=2, v_num=3, val_loss=2.200, val_acc=0.409, train_acc=0.523, test_loss=2.680, test_acc=0.482]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:14<00:00,  1.70it/s, loss=2, v_num=3, val_loss=2.160, val_acc=0.411, train_acc=0.523, test_loss=2.680, test_acc=0.482]
# Epoch 9: 100% 25/25 [00:14<00:00,  1.70it/s, loss=2, v_num=3, val_loss=2.160, val_acc=0.411, train_acc=0.534, test_loss=2.680, test_acc=0.482]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:14<00:00,  1.69it/s, loss=2, v_num=3, val_loss=2.160, val_acc=0.411, train_acc=0.534, test_loss=2.680, test_acc=0.482]
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.01s/it]average test f1 overlap @ 10%: 44.55128205128205
# average test f1 overlap @ 25%: 38.301282051282044
# average test f1 overlap @ 50%: 19.49786324786325
# average test edit: 51.51785714285714
# average test accuracy : 0.44891420006752014
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.01s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.44891417026519775
#         test_loss           2.3052549362182617
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▅▅▅█▄▄▂▁▁▁
# wandb:      average_val_edit ▁▁▁▄▆▅▇███
# wandb:     average_val_f1_10 ▁▁▁▆▅█▅▄▄▄
# wandb:     average_val_f1_25 ▁▁▁█▂▂▂▂▂▅
# wandb:     average_val_f1_50 ▁▁▁█▅▇▅▃▃▃
# wandb:            edit_score ▄▃▁▃▄▃▄▃▄▃▄▃▇█▁▂▂▂▁▂▂▂▁▂▂▂▁▁▂▂▂▂▂▂▂▂▂▂▂▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 █▁▂▃█▆█▇█▆█▇▆▆▁▂▂▂▁▂▃▂▂▂▂▃▂▃▃▃▃▃▃▂▃▂▃▂▃▂
# wandb:         f1_overlap_25 ▁▁▁▃█▆█▇█▆█▇▆▄▁▂▂▁▁▂▂▂▁▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▁
# wandb:         f1_overlap_50 ▁▁▁▆▁▁▁▁▁▁▁▁▁█▂▂▃▂▂▂▃▂▂▄▃▄▂▂▃▂▂▂▂▃▂▃▃▄▃▂
# wandb:         test_accuracy ▇▁▁█
# wandb:             test_loss ▁▁█▁
# wandb:        train_accuracy ▂▁▅▅▅▆▅▅▅▆▅▅▅▄▅▆▅▄▆▇▆▅▆▇▅▅▆▇█▆▆▇█▅▆▇█▅▆▅
# wandb:            train_loss ████▇██▇▇▆▇▅▇▆▆▆█▅▆▅▅▅▅▄▆▆▇▄▄▆▆▄▄▆▇▃▃▆▇▁
# wandb:          val_accuracy ▆█▂▄▆█▂▄▆█▂▄▆▂▇▄▄▂▆▄▄▁▇▄▄▁▇▄▄▁▆▄▄▁▆▄▄▁▆▄
# wandb:        val_edit_score ▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃█▅▆▃▆▃▆▃█▆█▃█▆█▆█▄█▆█▆██
# wandb:     val_f1_overlap_10 ▃▃▃▃▃▃▃▃▃▃▃▃▆▂▆▂▄▃▇▂▅▂█▂▄▁▇▂▄▁▇▂▄▁▇▂▄▁▇▄
# wandb:     val_f1_overlap_25 ▃▃▃▃▃▃▃▃▃▃▃▃▆▂▆▂▁▃▄▂▂▂█▂▄▁▇▂▄▁▇▂▄▁▇▂▄▁▇▄
# wandb:     val_f1_overlap_50 ▅▅▁▁▅▅▁▁▅▅▁▁▅▁█▅▃▁▆▅▄▁▇▅▄▁▆▅▄▁▄▄▄▁▄▄▄▁▄▄
# wandb:              val_loss ▇▇▇▇▆▆▇▆▆▅▇▆▅█▅▆▄█▄▅▄█▃▅▄█▃▄▃█▂▃▃▇▁▃▂▇▁▅
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.44891
# wandb:     average_test_edit 51.51786
# wandb:    average_test_f1_10 44.55128
# wandb:    average_test_f1_25 38.30128
# wandb:    average_test_f1_50 19.49786
# wandb:  average_val_accuracy 0.41086
# wandb:      average_val_edit 72.0
# wandb:     average_val_f1_10 40.11111
# wandb:     average_val_f1_25 40.11111
# wandb:     average_val_f1_50 18.33333
# wandb:            edit_score 3.79147
# wandb:                 epoch 9
# wandb:         f1_overlap_10 2.72727
# wandb:         f1_overlap_25 1.81818
# wandb:         f1_overlap_50 0.90909
# wandb:         test_accuracy 0.61616
# wandb:             test_loss 1.61593
# wandb:        train_accuracy 0.44266
# wandb:            train_loss 1.39639
# wandb:          val_accuracy 0.40256
# wandb:        val_edit_score 80.0
# wandb:     val_f1_overlap_10 44.44444
# wandb:     val_f1_overlap_25 44.44444
# wandb:     val_f1_overlap_50 22.22222
# wandb:              val_loss 2.41112
# wandb:
# wandb: Synced bright-sound-6: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/1jsq2mdk
# wandb: Synced 5 W&B file(s), 54 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_140937-1jsq2mdk/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_141248-2971ehx0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colorful-water-7
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/2971ehx0
# STARTING FOLD 3
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:29<00:07,  1.45s/it, loss=2.86, v_num=3, val_loss=2.160, val_acc=0.411, train_acc=0.534, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:34<00:00,  1.38s/it, loss=2.86, v_num=3, val_loss=2.910, val_acc=0.379, train_acc=0.534, test_loss=2.310, test_acc=0.449]
# Epoch 1:  80% 20/25 [00:14<00:03,  1.36it/s, loss=2.77, v_num=3, val_loss=2.910, val_acc=0.379, train_acc=0.286, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:18<00:00,  1.32it/s, loss=2.77, v_num=3, val_loss=2.880, val_acc=0.379, train_acc=0.286, test_loss=2.310, test_acc=0.449]
# Epoch 2:  80% 20/25 [00:14<00:03,  1.38it/s, loss=2.62, v_num=3, val_loss=2.880, val_acc=0.379, train_acc=0.442, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:18<00:00,  1.35it/s, loss=2.62, v_num=3, val_loss=3.030, val_acc=0.379, train_acc=0.442, test_loss=2.310, test_acc=0.449]
# Epoch 3:  80% 20/25 [00:14<00:03,  1.41it/s, loss=2.46, v_num=3, val_loss=3.030, val_acc=0.379, train_acc=0.442, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:18<00:00,  1.36it/s, loss=2.46, v_num=3, val_loss=3.290, val_acc=0.439, train_acc=0.442, test_loss=2.310, test_acc=0.449]
# Epoch 4:  80% 20/25 [00:14<00:03,  1.42it/s, loss=2.32, v_num=3, val_loss=3.290, val_acc=0.439, train_acc=0.458, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:18<00:00,  1.35it/s, loss=2.32, v_num=3, val_loss=3.130, val_acc=0.372, train_acc=0.458, test_loss=2.310, test_acc=0.449]
# Epoch 5:  80% 20/25 [00:27<00:06,  1.40s/it, loss=2.11, v_num=3, val_loss=3.130, val_acc=0.372, train_acc=0.496, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:33<00:00,  1.32s/it, loss=2.11, v_num=3, val_loss=3.340, val_acc=0.371, train_acc=0.496, test_loss=2.310, test_acc=0.449]
# Epoch 6:  80% 20/25 [00:16<00:04,  1.24it/s, loss=2.18, v_num=3, val_loss=3.340, val_acc=0.371, train_acc=0.525, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:20<00:00,  1.24it/s, loss=2.18, v_num=3, val_loss=2.950, val_acc=0.368, train_acc=0.525, test_loss=2.310, test_acc=0.449]
# Epoch 7:  80% 20/25 [00:14<00:03,  1.40it/s, loss=2.03, v_num=3, val_loss=2.950, val_acc=0.368, train_acc=0.514, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:18<00:00,  1.36it/s, loss=2.03, v_num=3, val_loss=2.960, val_acc=0.372, train_acc=0.514, test_loss=2.310, test_acc=0.449]
# Epoch 8:  80% 20/25 [00:14<00:03,  1.36it/s, loss=1.89, v_num=3, val_loss=2.960, val_acc=0.372, train_acc=0.532, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:18<00:00,  1.33it/s, loss=1.89, v_num=3, val_loss=3.030, val_acc=0.388, train_acc=0.532, test_loss=2.310, test_acc=0.449]
# Epoch 9:  80% 20/25 [00:14<00:03,  1.38it/s, loss=1.89, v_num=3, val_loss=3.030, val_acc=0.388, train_acc=0.539, test_loss=2.310, test_acc=0.449]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:18<00:00,  1.32it/s, loss=1.89, v_num=3, val_loss=2.810, val_acc=0.401, train_acc=0.539, test_loss=2.310, test_acc=0.449]
# Epoch 9: 100% 25/25 [00:18<00:00,  1.32it/s, loss=1.89, v_num=3, val_loss=2.810, val_acc=0.401, train_acc=0.545, test_loss=2.310, test_acc=0.449]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:19<00:00,  1.31it/s, loss=1.89, v_num=3, val_loss=2.810, val_acc=0.401, train_acc=0.545, test_loss=2.310, test_acc=0.449]
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.03s/it]average test f1 overlap @ 10%: 46.43578643578643
# average test f1 overlap @ 25%: 38.499278499278496
# average test f1 overlap @ 50%: 31.57287157287157
# average test edit: 51.30952380952381
# average test accuracy : 0.5325227975845337
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.03s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.5325227975845337
#         test_loss           2.6220836639404297
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▂▂▂█▁▁▁▁▃▄
# wandb:      average_val_edit ▁▁▁▄▆█▆██▇
# wandb:     average_val_f1_10 ▁▁▁▅▇▇▅▅██
# wandb:     average_val_f1_25 ▁▁▁▅▄▅▄▆▇█
# wandb:     average_val_f1_50 ▁▁▁▆▆▇▆▇█▆
# wandb:            edit_score ▅▅▂▂▅▅▅▅▅▅▅▅▅▅▄█▂▂▂▅▃▂▂▆▃▂▃▆▁▂▃▃▁▂▂▄▁▂▃▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 █▁▃▂██████████▃▄▂▃▂▃▃▂▂▃▃▃▄▃▂▃▅▃▁▃▃▂▁▃▃▂
# wandb:         f1_overlap_25 ▁▁▃▂██████████▃▄▂▁▁▃▂▂▂▃▂▂▂▃▁▂▄▃▁▂▂▂▁▃▃▂
# wandb:         f1_overlap_50 ▁▁▃▂▁▁█▁▁▁█▁▁█▃▄▂▁▁▃▂▂▁▃▂▂▂▃▁▂▂▃▁▂▂▂▁▂▂▁
# wandb:         test_accuracy ▅▁▃█
# wandb:             test_loss ▁▄█▁
# wandb:        train_accuracy ▂▁▆▅▄▄▆▅▄▄▆▅▄▆▆▅▅█▇▅▅▇▇▅▅▇▆▅▄██▅▃█▇▅▃█▇▆
# wandb:            train_loss ██████▇█▇▇▆█▇▅▄█▆▃▂▇▅▃▂█▃▁▂▇▅▃▂█▅▃▁▇▅▂▁▂
# wandb:          val_accuracy ▄▃▅▂▄▃▅▂▄▃▅▂▇▆▄▂▆▇▁▂▆▆▁▂▅▇▁▂▄█▁▂▅█▁▂▆█▁▄
# wandb:        val_edit_score ▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▄▆▆▆▄██▆▇▆▆▆▇██▅▇██▆▇██▁▆
# wandb:     val_f1_overlap_10 ▂▂▂▂▂▂▂▂▂▂▂▂▄▄▄▂▆▆▁▂▆▆▃▁▄▆▁▁▃▆▂▁▆█▃▁▆█▁▆
# wandb:     val_f1_overlap_25 ▂▂▂▃▂▂▂▃▂▂▂▃▂▅▂▂▄▄▂▂▄▄▁▂▂▇▂▂▄▆▁▂▄█▁▂▄█▂▃
# wandb:     val_f1_overlap_50 ▁▁▁▁▁▁▁▁▁▁▁▁▅▅▁▁▅▅▁▁█▅▁▁▅▅▁▁▅█▁▁██▁▁█▅▁▃
# wandb:              val_loss ▅▅▅▅▅▅▅▅▅▅▆▅▆▆█▅▆▆▇▅█▇█▅▆▆▆▅▇▆▅▅▇▆▅▆▆▅▅▁
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.53252
# wandb:     average_test_edit 51.30952
# wandb:    average_test_f1_10 46.43579
# wandb:    average_test_f1_25 38.49928
# wandb:    average_test_f1_50 31.57287
# wandb:  average_val_accuracy 0.401
# wandb:      average_val_edit 53.41414
# wandb:     average_val_f1_10 50.20588
# wandb:     average_val_f1_25 41.20588
# wandb:     average_val_f1_50 14.5
# wandb:            edit_score 4.58716
# wandb:                 epoch 9
# wandb:         f1_overlap_10 3.50877
# wandb:         f1_overlap_25 3.50877
# wandb:         f1_overlap_50 1.75439
# wandb:         test_accuracy 0.85859
# wandb:             test_loss 1.28912
# wandb:        train_accuracy 0.5572
# wandb:            train_loss 1.54865
# wandb:          val_accuracy 0.38229
# wandb:        val_edit_score 55.55556
# wandb:     val_f1_overlap_10 62.5
# wandb:     val_f1_overlap_25 37.5
# wandb:     val_f1_overlap_50 12.5
# wandb:              val_loss 1.69398
# wandb:
# wandb: Synced colorful-water-7: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/2971ehx0
# wandb: Synced 5 W&B file(s), 54 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_141248-2971ehx0/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_141641-gjmfg2uc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run apricot-elevator-8
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/gjmfg2uc
# STARTING FOLD 4
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:  80% 20/25 [00:32<00:08,  1.63s/it, loss=2.88, v_num=3, val_loss=2.810, val_acc=0.401, train_acc=0.545, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0: 100% 25/25 [00:38<00:00,  1.54s/it, loss=2.88, v_num=3, val_loss=2.850, val_acc=0.400, train_acc=0.545, test_loss=2.620, test_acc=0.533]
# Epoch 1:  80% 20/25 [00:17<00:04,  1.14it/s, loss=2.83, v_num=3, val_loss=2.850, val_acc=0.400, train_acc=0.253, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1: 100% 25/25 [00:22<00:00,  1.13it/s, loss=2.83, v_num=3, val_loss=2.820, val_acc=0.400, train_acc=0.253, test_loss=2.620, test_acc=0.533]
# Epoch 2:  80% 20/25 [00:19<00:04,  1.05it/s, loss=2.78, v_num=3, val_loss=2.820, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2: 100% 25/25 [00:23<00:00,  1.06it/s, loss=2.78, v_num=3, val_loss=2.770, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Epoch 3:  80% 20/25 [00:17<00:04,  1.15it/s, loss=2.71, v_num=3, val_loss=2.770, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3: 100% 25/25 [00:22<00:00,  1.12it/s, loss=2.71, v_num=3, val_loss=2.710, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Epoch 4:  80% 20/25 [00:17<00:04,  1.14it/s, loss=2.59, v_num=3, val_loss=2.710, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4: 100% 25/25 [00:22<00:00,  1.13it/s, loss=2.59, v_num=3, val_loss=2.640, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Epoch 5:  80% 20/25 [00:35<00:08,  1.75s/it, loss=2.46, v_num=3, val_loss=2.640, val_acc=0.400, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5: 100% 25/25 [00:41<00:00,  1.66s/it, loss=2.46, v_num=3, val_loss=2.500, val_acc=0.411, train_acc=0.437, test_loss=2.620, test_acc=0.533]
# Epoch 6:  80% 20/25 [00:17<00:04,  1.14it/s, loss=2.3, v_num=3, val_loss=2.500, val_acc=0.411, train_acc=0.447, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6: 100% 25/25 [00:22<00:00,  1.13it/s, loss=2.3, v_num=3, val_loss=2.400, val_acc=0.434, train_acc=0.447, test_loss=2.620, test_acc=0.533]
# Epoch 7:  80% 20/25 [00:19<00:04,  1.02it/s, loss=2.31, v_num=3, val_loss=2.400, val_acc=0.434, train_acc=0.485, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7: 100% 25/25 [00:24<00:00,  1.03it/s, loss=2.31, v_num=3, val_loss=2.350, val_acc=0.473, train_acc=0.485, test_loss=2.620, test_acc=0.533]
# Epoch 8:  80% 20/25 [00:17<00:04,  1.13it/s, loss=2.16, v_num=3, val_loss=2.350, val_acc=0.473, train_acc=0.486, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8: 100% 25/25 [00:22<00:00,  1.11it/s, loss=2.16, v_num=3, val_loss=2.290, val_acc=0.555, train_acc=0.486, test_loss=2.620, test_acc=0.533]
# Epoch 9:  80% 20/25 [00:19<00:04,  1.01it/s, loss=2.11, v_num=3, val_loss=2.290, val_acc=0.555, train_acc=0.509, test_loss=2.620, test_acc=0.533]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9: 100% 25/25 [00:24<00:00,  1.03it/s, loss=2.11, v_num=3, val_loss=2.220, val_acc=0.594, train_acc=0.509, test_loss=2.620, test_acc=0.533]
# Epoch 9: 100% 25/25 [00:24<00:00,  1.03it/s, loss=2.11, v_num=3, val_loss=2.220, val_acc=0.594, train_acc=0.530, test_loss=2.620, test_acc=0.533]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 25/25 [00:24<00:00,  1.02it/s, loss=2.11, v_num=3, val_loss=2.220, val_acc=0.594, train_acc=0.530, test_loss=2.620, test_acc=0.533]
# Testing DataLoader 0: 100% 4/4 [00:05<00:00,  1.34s/it]average test f1 overlap @ 10%: 38.11507936507937
# average test f1 overlap @ 25%: 38.11507936507937
# average test f1 overlap @ 50%: 25.753968253968253
# average test edit: 44.31818181818181
# average test accuracy : 0.43447256088256836
# Testing DataLoader 0: 100% 4/4 [00:05<00:00,  1.35s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.43447256088256836
#         test_loss           2.3145065307617188
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb: average_test_accuracy ▁
# wandb:     average_test_edit ▁
# wandb:    average_test_f1_10 ▁
# wandb:    average_test_f1_25 ▁
# wandb:    average_test_f1_50 ▁
# wandb:  average_val_accuracy ▁▁▁▁▁▁▂▄▇█
# wandb:      average_val_edit ▁▁▁▁▁▄▄▅▇█
# wandb:     average_val_f1_10 ▁▁▁▁▁▁▂▄▆█
# wandb:     average_val_f1_25 ▁▁▁▁▁▁▂▄▆█
# wandb:     average_val_f1_50 ▁▁▁▁▁▃▃▅▇█
# wandb:            edit_score ▄▄▁▆▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄█▃▂▂▂▁▂▁▂▁▂▁▁▁▂▁▂▁▁
# wandb:                 epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:         f1_overlap_10 █▁▂▄███▇███▇█████████▆▂▂▂▂▂▃▂▂▂▂▁▂▂▂▁▃▂▂
# wandb:         f1_overlap_25 ▁▁▁▄███▇███▇█████████▆▂▂▂▂▁▂▁▂▁▂▁▂▁▂▁▂▂▁
# wandb:         f1_overlap_50 ▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄▃▃▂▂▂▁▂▂▂▁▂▂▄▁▂▃▁
# wandb:         test_accuracy ▅▁▃█
# wandb:             test_loss ▂▂█▁
# wandb:        train_accuracy ▂▁▄▅▄▄▅▅▄▄▅▅▄▅▅▅▄▅▅▅▄▅▅▅▅▆▆▆▄▆▆▆▄▇▆▆▄█▆▅
# wandb:            train_loss ▇▇██▇▇██▇▇▇▇▇▇▇▆▇▇▆▆█▇▄▅▇▇█▄▅▇█▃▄▅█▂▅▄█▁
# wandb:          val_accuracy ▃▄▁▁▃▄▁▁▃▄▁▁▃▄▁▁▃▄▁▁▃▄▂▁▃▅▂▁▃▅▂▂▅█▃▂▆▇▄▃
# wandb:        val_edit_score ▂▂▁▂▂▂▁▂▂▂▁▂▂▂▁▂▂▂▁▂▄▄▃▄▄▄▃▄▄▅▄▄▆█▄▃▆█▄▄
# wandb:     val_f1_overlap_10 ▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▂▂▃▃▂▁▅▅▄▄█▅▂▇█▅▂
# wandb:     val_f1_overlap_25 ▄▄▁▄▄▄▁▄▄▄▁▄▄▄▁▄▄▄▁▄▃▃▃▃▃▅▃▃▃▄▅▅▅█▆▂▇█▆▃
# wandb:     val_f1_overlap_50 ▁▅▁▁▁▅▁▁▁▅▁▁▁▅▁▁▁▅▁▁▄▄▁▁▄▃▁▁▃▅▃▁▅█▁▁▄▆▃▁
# wandb:              val_loss ████▇▇██▇▇█▇▇▆▇█▇▅▆█▆▃▅▇▆▂▅█▄▂▆▆▃▁▅▆▂▁▅▆
# wandb:
# wandb: Run summary:
# wandb: average_test_accuracy 0.43447
# wandb:     average_test_edit 44.31818
# wandb:    average_test_f1_10 38.11508
# wandb:    average_test_f1_25 38.11508
# wandb:    average_test_f1_50 25.75397
# wandb:  average_val_accuracy 0.59408
# wandb:      average_val_edit 56.57143
# wandb:     average_val_f1_10 60.49206
# wandb:     average_val_f1_25 60.49206
# wandb:     average_val_f1_50 22.88889
# wandb:            edit_score 2.97872
# wandb:                 epoch 9
# wandb:         f1_overlap_10 2.45902
# wandb:         f1_overlap_25 0.81967
# wandb:         f1_overlap_50 0.81967
# wandb:         test_accuracy 0.6936
# wandb:             test_loss 1.59062
# wandb:        train_accuracy 0.4326
# wandb:            train_loss 1.59457
# wandb:          val_accuracy 0.43443
# wandb:        val_edit_score 40.0
# wandb:     val_f1_overlap_10 28.57143
# wandb:     val_f1_overlap_25 28.57143
# wandb:     val_f1_overlap_50 0.0
# wandb:              val_loss 2.50593
# wandb:
# wandb: Synced apricot-elevator-8: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/gjmfg2uc
# wandb: Synced 5 W&B file(s), 54 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_141641-gjmfg2uc/logs
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/run-20220818_142128-cgkw0qf7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sandy-wood-9
# wandb: ⭐️ View project at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT
# wandb: 🚀 View run at https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/cgkw0qf7
# Testing DataLoader 0:   0% 0/4 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "cnn_tcn_lstm_kfold.py", line 118, in <module>
#     main(args.filename)
#   File "cnn_tcn_lstm_kfold.py", line 105, in main
#     trainer.fit(model, datamodule)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 697, in fit
#     self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 650, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 737, in _fit_impl
#     results = self._run(model, ckpt_path=self.ckpt_path)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 1168, in _run
#     results = self._run_stage()
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 1254, in _run_stage
#     return self._run_train()
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 1285, in _run_train
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/loop.py", line 207, in run
#     output = self.on_run_end()
#   File "/content/drive/Othercomputers/Dell/Action-Segmentation-Project/utils/kfold_datamodule/cnn_tcn_lstm_kfold_image_datamodule.py", line 337, in on_run_end
#     self.trainer.test_loop.run()
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/loop.py", line 200, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py", line 155, in advance
#     dl_outputs = self.epoch_loop.run(self._data_fetcher, dl_max_batches, kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/loop.py", line 200, in run
#     self.advance(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 143, in advance
#     output = self._evaluation_step(**kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/epoch/evaluation_epoch_loop.py", line 240, in _evaluation_step
#     output = self.trainer._call_strategy_hook(hook_name, *kwargs.values())
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py", line 1706, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pytorch_lightning/strategies/strategy.py", line 379, in test_step
#     return self.model.test_step(*args, **kwargs)
#   File "/content/drive/Othercomputers/Dell/Action-Segmentation-Project/utils/kfold_datamodule/cnn_tcn_lstm_kfold_image_datamodule.py", line 203, in test_step
#     preds, targets = remove_padding_img(logits, y)
#   File "/content/drive/Othercomputers/Dell/Action-Segmentation-Project/utils/image_preprocessing.py", line 90, in remove_padding_img
#     outputs = predictions_padded.squeeze()[:n, :]  # T x n_classes
# AttributeError: 'list' object has no attribute 'squeeze'
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Synced sandy-wood-9: https://wandb.ai/soniamathews/CNN_TCN_LSTM_KFOLD_Single_MT/runs/cgkw0qf7
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220818_142128-cgkw0qf7/logs

# %%
! python main_2.py -f encoder_decoder_baseline.yaml
