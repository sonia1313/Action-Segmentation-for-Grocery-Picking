# %%
import os
from google.colab import drive 

drive.mount('/content/drive', force_remount=True)

# %%
import torch

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
PATH_TO_DIR  = "/content/drive/Othercomputers/Dell"
if torch.cuda.is_available():
  print(torch.cuda.get_device_properties(device).name)

os.chdir(PATH_TO_DIR)

# %%
# !pwd
# !pip install pytorch_lightning
# !pip install wandb

# %%
# !pip install -q pytorch-lightning wandb
wandb.login()
# Out:
# True

# %%
import pytorch_lightning as pl
import torch
import wandb

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Action-Segmentation-Project' 
GOOGLE_DRIVE_PATH = os.path.join(PATH_TO_DIR, GOOGLE_DRIVE_PATH_AFTER_MYDRIVE )
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['=0.0.7', '.empty', '.idea', 'dataset', 'experiments', 'models', 'utils', 'hyperparams.py', '__pycache__', '.git', '.ipynb_checkpoints', 'checkpoints', 'action_segmentation_module.py', 'main.py']

# %%
import sys
modules_needed = ['dataset', 'experiments', 'models', 'utils', 'hyperparams.py','utils/offline_optoforce_datamodule.py', '.git', 'action_segmentation_module.py', 'lightning_logs', 'main.py']
for i in os.listdir(GOOGLE_DRIVE_PATH):
    if i not in sys.path:
      CODE_PATH = os.path.join(GOOGLE_DRIVE_PATH,i )
      sys.path.append(CODE_PATH)
sys.path.insert(0,GOOGLE_DRIVE_PATH)

# %%
import main

# %%
main.main()
# Out:
# Global seed set to 42
# Tesla P100-PCIE-16GB
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-6319b7863bf8> in <module>()
# ----> 1 main.main()
#
# /content/drive/Othercomputers/Dell/Action-Segmentation-Project/main.py in main()
#      57     pl.seed_everything(42, workers=True)
#      58     checkpoint_callback = ModelCheckpoint(dirpath='//content/drive/Othercomputers/Dell/Action-Segmentation-Project/lightning_logs', save_top_k=2, monitor="val_loss")
# ---> 59     logger = WandbLogger(project = "Action_Segmentation", log_model='all')
#      60     trainer = pl.Trainer(default_root_dir=f"{PATH_TO_DIR}/checkpoints",  gpus=n_gpu, max_epochs=10, deterministic=True,progress_bar_refresh_rate=20, logger=logger)
#      61
#
# ...
