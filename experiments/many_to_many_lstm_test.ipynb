# %%
import os
from google.colab import drive 

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
PATH_TO_DIR  = "/content/drive/Othercomputers/Dell"
if torch.cuda.is_available():
  print(torch.cuda.get_device_properties(device).name)

os.chdir(PATH_TO_DIR)
# Out:
# cuda:0
# Tesla P100-PCIE-16GB

# %%
# !pwd
# !pip install pytorch_lightning
# !pip install wandb
# Out:
# /content/drive/Othercomputers/Dell

# %%
# !pip install -q pytorch-lightning wandb

# %%
import pytorch_lightning as pl
import torch
import wandb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Action-Segmentation-Project' 
GOOGLE_DRIVE_PATH = os.path.join(PATH_TO_DIR, GOOGLE_DRIVE_PATH_AFTER_MYDRIVE )
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['=0.0.7', '.empty', '.idea', 'dataset', 'experiments', 'models', 'utils', 'hyperparams.py', '__pycache__', '.git', '.ipynb_checkpoints', 'checkpoints', 'wandb', 'DysonLab_interview_prep.docx', 'testing_kfold', 'lightning_logs', 'tests', 'action_segmentation_module.py', 'main.py']

# %%
import sys
modules_needed = ['dataset', 'experiments', 'models', 'utils', 'hyperparams.py','utils/offline_optoforce_datamodule.py', '.git', 'action_segmentation_module.py', 'lightning_logs', 'main.py']
for i in os.listdir(GOOGLE_DRIVE_PATH):
    if i not in sys.path:
      CODE_PATH = os.path.join(GOOGLE_DRIVE_PATH,i )
      sys.path.append(CODE_PATH)
sys.path.insert(0,GOOGLE_DRIVE_PATH)

# %%
import main

# %%
main.main()
# Out:
# Global seed set to 42
# Tesla P100-PCIE-16GB
# Tracking run with wandb version 0.12.20
# Run data is saved locally in <code>/content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/wandb/run-20220630_094017-39nlpjod</code>
# Syncing run <strong><a href="https://wandb.ai/soniamathews/Action_Segmentation/runs/39nlpjod" target="_blank">silvery-disco-28</a></strong> to <a href="https://wandb.ai/soniamathews/Action_Segmentation" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:97: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type             | Params
# -------------------------------------------------
# 0 | model       | ManyToManyLSTM   | 42.6 K
# 1 | loss_module | CrossEntropyLoss | 0
# 2 | train_acc   | Accuracy         | 0
# 3 | val_acc     | Accuracy         | 0
# 4 | test_acc    | Accuracy         | 0
# -------------------------------------------------
# 42.6 K    Trainable params
# 0         Non-trainable params
# 42.6 K    Total params
# 0.170     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1937: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1447: UserWarning: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `test(ckpt_path='best')` to use and best model checkpoint and avoid this warning or `ckpt_path=trainer.checkpoint_callback.last_model_path` to use the last model.
#   f"`.{fn}(ckpt_path=None)` was called without a model."
# Restoring states from the checkpoint path at /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/Action_Segmentation/39nlpjod/checkpoints/epoch=19-step=400.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from checkpoint at /content/drive/Othercomputers/Dell/Action-Segmentation-Project/wandb/Action_Segmentation/39nlpjod/checkpoints/epoch=19-step=400.ckpt
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.42399293184280396
#         test_loss            1.476747751235962
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='9.897 MB of 9.897 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▁▁▁▂▇███▇▇▇▇▆▆▇▇▇▇▇</td></tr><tr><td>train_loss</td><td>████▇▇▇▇▇▆▆▅▄▂▂▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>val_acc</td><td>▁▁▁▁▄▅██████▇▇▇▇▇▇▇▇</td></tr><tr><td>val_loss</td><td>████▇▇▇▇▇▆▆▅▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>19</td></tr><tr><td>test_acc</td><td>0.42399</td></tr><tr><td>test_loss</td><td>1.47675</td></tr><tr><td>train_acc</td><td>0.45055</td></tr><tr><td>train_loss</td><td>1.36027</td></tr><tr><td>trainer/global_step</td><td>400</td></tr><tr><td>val_acc</td><td>0.43708</td></tr><tr><td>val_loss</td><td>1.432</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">silvery-disco-28</strong>: <a href="https://wandb.ai/soniamathews/Action_Segmentation/runs/39nlpjod" target="_blank">https://wandb.ai/soniamathews/Action_Segmentation/runs/39nlpjod</a><br/>Synced 5 W&B file(s), 0 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./Action-Segmentation-Project/wandb/wandb/run-20220630_094017-39nlpjod/logs</code>
